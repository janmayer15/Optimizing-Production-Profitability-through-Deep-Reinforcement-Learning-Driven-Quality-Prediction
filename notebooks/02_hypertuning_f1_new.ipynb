# %% [markdown]
# # Installation Requirements

# %%
# !pip uninstall --quiet tensorflow --yes
# !pip uninstall --quiet kapre --yes
# !pip install --quiet tensorflow==1.14.0
# !pip install --quiet stable_baselines
# !pip uninstall --quiet optuna --yes
# !pip install --quiet optuna==2.10.0
# !pip uninstall --quiet tensorboard-plugin-wit --yes
# !pip install --quiet "gym==0.19.0"
# Out:
# WARNING: Skipping kapre as it is not installed.
# WARNING: Skipping tensorboard-plugin-wit as it is not installed.

# %%
# Set working directory
# %cd /content/drive/MyDrive/ColabNotebooks/Masterarbeit/RLModel/src

# run config.py to load all required settings  
# %run config.py
# Out:
# /content/drive/MyDrive/ColabNotebooks/Masterarbeit/RLModel/src

# %% [markdown]
# # Optimize f1

# %%
# !python -W ignore hypertrain.py --path '../models/hypertuning/optimize_f1_new/' --study_name 'hyperstudy_f1_new' --timesteps 50000 --cross_validation 'f1' --save_every_x_steps 5000 --val_eval_freq 5000 --trials 30
# Out:
# Streaming output truncated to the last 5000 lines.
# [84.00%/100%] train_steps 42000 (eps 5818), mean_reward: 0.38 +/- 0.66, acc: 0.80, mean_timesteps: 7.22 +/- 13.37
# [85.00%/100%] train_steps 42500 (eps 5869), mean_reward: 0.33 +/- 1.04, acc: 0.82, mean_timesteps: 8.36 +/- 20.45
# [86.00%/100%] train_steps 43000 (eps 5905), mean_reward: 0.20 +/- 1.17, acc: 0.74, mean_timesteps: 9.68 +/- 23.73
# [87.00%/100%] train_steps 43500 (eps 5937), mean_reward: 0.11 +/- 1.27, acc: 0.72, mean_timesteps: 11.73 +/- 27.43
# [88.00%/100%] train_steps 44000 (eps 5983), mean_reward: 0.11 +/- 1.24, acc: 0.75, mean_timesteps: 13.07 +/- 27.42
# [89.00%/100%] train_steps 44500 (eps 6035), mean_reward: 0.20 +/- 0.71, acc: 0.73, mean_timesteps: 10.52 +/- 18.19
# [90.00%/100%] train_steps 45000 (eps 6095), mean_reward: 0.31 +/- 0.71, acc: 0.76, mean_timesteps: 8.44 +/- 17.02
# save model...
# Evaluation on VALIDATION DATA - mean_reward: 0.55 +/- 0.51, acc: 0.82, mean_timesteps: 2.05 +/- 2.14, f1: 0.06
# ...

# %%
# !python -W ignore hypertrain.py --path '../models/hypertuning/optimize_f1_new/' --study_name 'hyperstudy_f1_new' --timesteps 50000 --cross_validation 'f1' --save_every_x_steps 5000 --val_eval_freq 5000  --trials 1 --enqueue_trial 15
# Out:
# Split_1
#
# ---------------------------------------------------------------------------------------
# Model Evaluation on TRAINING DATA (last 100 episodes)
# ---------------------------------------------------------------------------------------
# [1.00%/100%] train_steps 500 (eps 470), mean_reward: -0.37 +/- 0.73, acc: 0.25, mean_timesteps: 1.03 +/- 0.17
# [2.00%/100%] train_steps 1000 (eps 930), mean_reward: -0.39 +/- 0.71, acc: 0.24, mean_timesteps: 1.09 +/- 0.29
# [3.00%/100%] train_steps 1500 (eps 1394), mean_reward: -0.33 +/- 0.75, acc: 0.28, mean_timesteps: 1.07 +/- 0.26
# [4.00%/100%] train_steps 2000 (eps 1861), mean_reward: -0.38 +/- 0.71, acc: 0.25, mean_timesteps: 1.08 +/- 0.31
# [5.00%/100%] train_steps 2500 (eps 2330), mean_reward: 0.67 +/- 0.61, acc: 0.78, mean_timesteps: 1.06 +/- 0.28
# [6.00%/100%] train_steps 3000 (eps 2788), mean_reward: 0.71 +/- 0.58, acc: 0.81, mean_timesteps: 1.14 +/- 0.40
# ...

# %%
# !python -W ignore hypertrain.py --path '../models/hypertuning/optimize_f1_new/' --study_name 'hyperstudy_f1_new' --timesteps 50000 --cross_validation 'f1' --save_every_x_steps 5000 --val_eval_freq 5000 --trials 15 --optimize_again
# Out:
# Split_1
#
# ---------------------------------------------------------------------------------------
# Model Evaluation on TRAINING DATA (last 100 episodes)
# ---------------------------------------------------------------------------------------
# [1.00%/100%] train_steps 500 (eps 415), mean_reward: 0.67 +/- 0.64, acc: 0.79, mean_timesteps: 1.27 +/- 1.08
# [2.00%/100%] train_steps 1000 (eps 832), mean_reward: 0.64 +/- 0.66, acc: 0.77, mean_timesteps: 1.17 +/- 0.66
# [3.00%/100%] train_steps 1500 (eps 1307), mean_reward: 0.70 +/- 0.63, acc: 0.81, mean_timesteps: 1.05 +/- 0.22
# [4.00%/100%] train_steps 2000 (eps 1787), mean_reward: 0.65 +/- 0.64, acc: 0.77, mean_timesteps: 1.04 +/- 0.20
# [5.00%/100%] train_steps 2500 (eps 2232), mean_reward: 0.66 +/- 0.64, acc: 0.78, mean_timesteps: 1.09 +/- 0.35
# [6.00%/100%] train_steps 3000 (eps 2676), mean_reward: 0.69 +/- 0.63, acc: 0.80, mean_timesteps: 1.13 +/- 0.36
# ...

# %%
# !python -W ignore hypertrain.py --path '../models/hypertuning/optimize_f1_new/' --study_name 'hyperstudy_f1_new' --timesteps 50000 --cross_validation 'f1' --save_every_x_steps 5000 --val_eval_freq 5000  --trials 1 --enqueue_trial 29
# Out:
# Split_1
#
# ---------------------------------------------------------------------------------------
# Model Evaluation on TRAINING DATA (last 100 episodes)
# ---------------------------------------------------------------------------------------
# [1.00%/100%] train_steps 500 (eps 181), mean_reward: -0.20 +/- 0.66, acc: 0.45, mean_timesteps: 2.93 +/- 1.42
# [2.00%/100%] train_steps 1000 (eps 360), mean_reward: -0.29 +/- 0.60, acc: 0.38, mean_timesteps: 2.79 +/- 1.42
# [3.00%/100%] train_steps 1500 (eps 526), mean_reward: -0.27 +/- 0.60, acc: 0.45, mean_timesteps: 2.90 +/- 1.36
# [4.00%/100%] train_steps 2000 (eps 703), mean_reward: -0.13 +/- 0.68, acc: 0.50, mean_timesteps: 2.92 +/- 1.64
# [5.00%/100%] train_steps 2500 (eps 880), mean_reward: -0.17 +/- 0.66, acc: 0.49, mean_timesteps: 2.94 +/- 1.54
# [6.00%/100%] train_steps 3000 (eps 1053), mean_reward: -0.27 +/- 0.63, acc: 0.44, mean_timesteps: 2.76 +/- 1.59
# ...

# %%
# !python -W ignore hypertrain.py --path '../models/hypertuning/optimize_f1_new/' --study_name 'hyperstudy_f1_new' --timesteps 50000 --cross_validation 'f1' --save_every_x_steps 5000 --val_eval_freq 5000  --trials 1 --enqueue_trial 35
# Out:
# Split_1
#
# ---------------------------------------------------------------------------------------
# Model Evaluation on TRAINING DATA (last 100 episodes)
# ---------------------------------------------------------------------------------------
# [1.00%/100%] train_steps 500 (eps 147), mean_reward: -0.23 +/- 0.69, acc: 0.42, mean_timesteps: 3.40 +/- 1.54
# [2.00%/100%] train_steps 1000 (eps 633), mean_reward: 0.24 +/- 0.29, acc: 0.85, mean_timesteps: 1.05 +/- 0.22
# [3.00%/100%] train_steps 1500 (eps 1009), mean_reward: 0.15 +/- 0.46, acc: 0.80, mean_timesteps: 1.19 +/- 0.48
# [4.00%/100%] train_steps 2000 (eps 1392), mean_reward: 0.16 +/- 0.44, acc: 0.78, mean_timesteps: 1.26 +/- 0.70
# [5.00%/100%] train_steps 2500 (eps 1754), mean_reward: 0.19 +/- 0.48, acc: 0.79, mean_timesteps: 1.29 +/- 0.73
# [6.00%/100%] train_steps 3000 (eps 2140), mean_reward: 0.24 +/- 0.42, acc: 0.86, mean_timesteps: 1.30 +/- 0.56
# ...

# %%
# !python -W ignore hypertrain.py --path '../models/hypertuning/optimize_f1_new/' --study_name 'hyperstudy_f1_new' --timesteps 50000 --cross_validation 'f1' --save_every_x_steps 5000 --val_eval_freq 5000 --trials 6 --optimize_again
# Out:
# Split_1
#
# ---------------------------------------------------------------------------------------
# Model Evaluation on TRAINING DATA (last 100 episodes)
# ---------------------------------------------------------------------------------------
# [1.00%/100%] train_steps 500 (eps 446), mean_reward: 0.45 +/- 0.62, acc: 0.75, mean_timesteps: 1.16 +/- 0.63
# [2.00%/100%] train_steps 1000 (eps 905), mean_reward: 0.53 +/- 0.56, acc: 0.80, mean_timesteps: 1.11 +/- 0.31
# [3.00%/100%] train_steps 1500 (eps 1346), mean_reward: 0.40 +/- 0.64, acc: 0.71, mean_timesteps: 1.12 +/- 0.41
# [4.00%/100%] train_steps 2000 (eps 1790), mean_reward: 0.42 +/- 0.64, acc: 0.73, mean_timesteps: 1.14 +/- 0.37
# [5.00%/100%] train_steps 2500 (eps 2242), mean_reward: 0.42 +/- 0.64, acc: 0.72, mean_timesteps: 1.11 +/- 0.37
# [6.00%/100%] train_steps 3000 (eps 2691), mean_reward: 0.39 +/- 0.66, acc: 0.71, mean_timesteps: 1.11 +/- 0.34
# ...

# %%
import optuna
import pandas as pd 

study_name = 'hyperstudy_f1_new'
storage_name = "sqlite:///{}.db".format(study_name)

study = optuna.load_study(study_name=study_name, storage=storage_name)
df = study.trials_dataframe(attrs=("number", "value", "params", "state"))
df.to_csv('test', sep=',')
