# %% [markdown]
# # Installation Requirements

# %%
# !pip uninstall --quiet tensorflow --yes
# !pip uninstall --quiet kapre --yes
# !pip install --quiet tensorflow==1.14.0
# !pip install --quiet stable_baselines
# !pip uninstall --quiet optuna --yes
# !pip install --quiet optuna==2.10.0
# !pip uninstall --quiet tensorboard-plugin-wit --yes
# !pip install --quiet "gym==0.19.0"
# Out:
#      |████████████████████████████████| 109.3 MB 45 kB/s
#      |████████████████████████████████| 488 kB 54.7 MB/s
#      |████████████████████████████████| 50 kB 6.4 MB/s
#      |████████████████████████████████| 3.1 MB 42.4 MB/s
#      |████████████████████████████████| 240 kB 7.4 MB/s
#      |████████████████████████████████| 18.3 MB 122 kB/s
#      |████████████████████████████████| 1.6 MB 46.7 MB/s
# WARNING: Skipping optuna as it is not installed.
#      |████████████████████████████████| 308 kB 6.6 MB/s
#      |████████████████████████████████| 209 kB 40.3 MB/s
#      |████████████████████████████████| 81 kB 8.9 MB/s
#      |████████████████████████████████| 78 kB 6.7 MB/s
#      |████████████████████████████████| 112 kB 51.4 MB/s
#      |████████████████████████████████| 147 kB 53.7 MB/s
#      |████████████████████████████████| 49 kB 6.1 MB/s
# ...
#      |████████████████████████████████| 1.6 MB 7.5 MB/s
# ...

# %%
# Set working directory
# %cd /content/drive/MyDrive/ColabNotebooks/Masterarbeit/RLModel/src

# run config.py to load all required settings  
# %run config.py
# Out:
# /content/drive/MyDrive/ColabNotebooks/Masterarbeit/RLModel/src
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %% [markdown]
# # Optimize GM

# %%
# !python -W ignore hypertrain.py --path '../models/hypertuning/optimize_gm/' --study_name 'hyperstudy_gm' --timesteps 50000 --cross_validation 'gm' --save_every_x_steps 5000 --val_eval_freq 5000  --trials 40
# Out:
# Streaming output truncated to the last 5000 lines.
# [43.00%/100%] train_steps 21500 (eps 1352), mean_reward: -0.15 +/- 0.76, acc: 0.52, mean_timesteps: 31.65 +/- 59.43
# [44.00%/100%] train_steps 22000 (eps 1370), mean_reward: -0.15 +/- 0.72, acc: 0.50, mean_timesteps: 27.75 +/- 53.25
# [45.00%/100%] train_steps 22500 (eps 1376), mean_reward: -0.20 +/- 0.76, acc: 0.48, mean_timesteps: 32.72 +/- 58.82
# [46.00%/100%] train_steps 23000 (eps 1409), mean_reward: -0.12 +/- 0.70, acc: 0.52, mean_timesteps: 26.10 +/- 51.27
# [47.00%/100%] train_steps 23500 (eps 1428), mean_reward: -0.12 +/- 0.71, acc: 0.53, mean_timesteps: 25.78 +/- 51.99
# [48.00%/100%] train_steps 24000 (eps 1447), mean_reward: -0.09 +/- 0.71, acc: 0.55, mean_timesteps: 24.97 +/- 51.28
# [49.00%/100%] train_steps 24500 (eps 1478), mean_reward: -0.05 +/- 0.69, acc: 0.56, mean_timesteps: 19.24 +/- 47.71
# [50.00%/100%] train_steps 25000 (eps 1502), mean_reward: -0.08 +/- 0.69, acc: 0.53, mean_timesteps: 20.14 +/- 47.45
# ...

# %%
# !python -W ignore hypertrain.py --path '../models/hypertuning/optimize_gm/' --study_name 'hyperstudy_gm' --timesteps 50000 --cross_validation 'gm' --save_every_x_steps 5000 --val_eval_freq 5000  --trials 1 --enqueue_trial 11
# Out:
# Split_1
#
# ---------------------------------------------------------------------------------------
# Model Evaluation on TRAINING DATA (last 100 episodes)
# ---------------------------------------------------------------------------------------
# [1.00%/100%] train_steps 500 (eps 477), mean_reward: 0.36 +/- 0.88, acc: 0.66, mean_timesteps: 1.01 +/- 0.10
# [2.00%/100%] train_steps 1000 (eps 958), mean_reward: 0.35 +/- 0.88, acc: 0.66, mean_timesteps: 1.04 +/- 0.20
# [3.00%/100%] train_steps 1500 (eps 1438), mean_reward: 0.39 +/- 0.88, acc: 0.68, mean_timesteps: 1.05 +/- 0.22
# [4.00%/100%] train_steps 2000 (eps 1921), mean_reward: 0.44 +/- 0.84, acc: 0.71, mean_timesteps: 1.02 +/- 0.14
# [5.00%/100%] train_steps 2500 (eps 2405), mean_reward: 0.61 +/- 0.75, acc: 0.80, mean_timesteps: 1.02 +/- 0.20
# [6.00%/100%] train_steps 3000 (eps 2887), mean_reward: 0.67 +/- 0.70, acc: 0.84, mean_timesteps: 1.05 +/- 0.26
# ...

# %%
# !python -W ignore hypertrain.py --path '../models/hypertuning/optimize_gm/' --study_name 'hyperstudy_gm' --timesteps 50000 --cross_validation 'gm' --save_every_x_steps 5000 --val_eval_freq 5000  --trials 29 --optimize_again
# Out:
# Streaming output truncated to the last 5000 lines.
# [22.00%/100%] train_steps 11000 (eps 3552), mean_reward: 0.13 +/- 0.52, acc: 0.79, mean_timesteps: 2.10 +/- 1.40
# [23.00%/100%] train_steps 11500 (eps 3777), mean_reward: 0.14 +/- 0.55, acc: 0.76, mean_timesteps: 2.24 +/- 1.46
# [24.00%/100%] train_steps 12000 (eps 4008), mean_reward: 0.12 +/- 0.54, acc: 0.76, mean_timesteps: 2.06 +/- 1.36
# [25.00%/100%] train_steps 12500 (eps 4264), mean_reward: 0.13 +/- 0.54, acc: 0.75, mean_timesteps: 1.99 +/- 1.32
# [26.00%/100%] train_steps 13000 (eps 4530), mean_reward: 0.13 +/- 0.53, acc: 0.77, mean_timesteps: 1.84 +/- 1.20
# [27.00%/100%] train_steps 13500 (eps 4789), mean_reward: 0.21 +/- 0.53, acc: 0.81, mean_timesteps: 2.00 +/- 1.28
# [28.00%/100%] train_steps 14000 (eps 5029), mean_reward: 0.19 +/- 0.53, acc: 0.81, mean_timesteps: 1.96 +/- 1.37
# [29.00%/100%] train_steps 14500 (eps 5295), mean_reward: 0.21 +/- 0.53, acc: 0.81, mean_timesteps: 2.00 +/- 1.47
# ...

# %%
# !python -W ignore hypertrain.py --path '../models/hypertuning/optimize_gm/' --study_name 'hyperstudy_gm' --timesteps 50000 --cross_validation 'gm' --save_every_x_steps 5000 --val_eval_freq 5000  --trials 1 --enqueue_trial 30
# Out:
# Split_1
#
# ---------------------------------------------------------------------------------------
# Model Evaluation on TRAINING DATA (last 100 episodes)
# ---------------------------------------------------------------------------------------
# [1.00%/100%] train_steps 500 (eps 68), mean_reward: 0.44 +/- 0.66, acc: 0.58, mean_timesteps: 5.19 +/- 19.66
# [2.00%/100%] train_steps 1000 (eps 116), mean_reward: 0.34 +/- 0.71, acc: 0.53, mean_timesteps: 8.95 +/- 33.43
# [3.00%/100%] train_steps 1500 (eps 140), mean_reward: 0.25 +/- 0.72, acc: 0.47, mean_timesteps: 11.16 +/- 38.14
# [4.00%/100%] train_steps 2000 (eps 165), mean_reward: 0.21 +/- 0.74, acc: 0.45, mean_timesteps: 15.14 +/- 44.50
# [5.00%/100%] train_steps 2500 (eps 176), mean_reward: 0.19 +/- 0.75, acc: 0.44, mean_timesteps: 16.99 +/- 47.24
# [6.00%/100%] train_steps 3000 (eps 185), mean_reward: 0.14 +/- 0.76, acc: 0.42, mean_timesteps: 20.81 +/- 52.10
# ...

# %%
# !python -W ignore hypertrain.py --path '../models/hypertuning/optimize_gm/' --study_name 'hyperstudy_gm' --timesteps 50000 --cross_validation 'gm' --save_every_x_steps 5000 --val_eval_freq 5000  --trials 11 --optimize_again
# Out:
# Split_1
#
# ---------------------------------------------------------------------------------------
# Model Evaluation on TRAINING DATA (last 100 episodes)
# ---------------------------------------------------------------------------------------
# [1.00%/100%] train_steps 500 (eps 285), mean_reward: -0.03 +/- 0.52, acc: 0.70, mean_timesteps: 1.69 +/- 1.93
# [2.00%/100%] train_steps 1000 (eps 505), mean_reward: -0.02 +/- 0.52, acc: 0.72, mean_timesteps: 1.74 +/- 1.45
# [3.00%/100%] train_steps 1500 (eps 662), mean_reward: -0.11 +/- 0.54, acc: 0.63, mean_timesteps: 3.30 +/- 6.20
# [4.00%/100%] train_steps 2000 (eps 857), mean_reward: -0.01 +/- 0.50, acc: 0.71, mean_timesteps: 1.89 +/- 2.27
# [5.00%/100%] train_steps 2500 (eps 1122), mean_reward: -0.04 +/- 0.53, acc: 0.70, mean_timesteps: 1.64 +/- 2.03
# [6.00%/100%] train_steps 3000 (eps 1358), mean_reward: -0.10 +/- 0.54, acc: 0.63, mean_timesteps: 1.89 +/- 2.42
# ...

# %%
import optuna
study_name = 'hyperstudy_gm'
storage_name = "sqlite:///{}.db".format(study_name)

study = optuna.load_study(study_name=study_name, storage=storage_name)
study.trials_dataframe(attrs=("number", "value", "params", "state"))
# Out:
#     number     value  params_batch_size  params_buffer_size  params_double_q  \
# 0        0  0.650691                 32               30000             True
# 1        1  0.773514                128               50000             True
# 2        2  0.780638                128               20000            False
# 3        3  0.788904                128                5000             True
# 4        4  0.640162                 32               40000            False
# 5        5  0.608120                 64                5000            False
# 6        6  0.738417                128                5000            False
# 7        7  0.768516                 64               40000            False
# 8        8  0.705092                 32                5000            False
# 9        9  0.779579                128               10000            False
# 10      10  0.768265                128               10000             True
# ...
