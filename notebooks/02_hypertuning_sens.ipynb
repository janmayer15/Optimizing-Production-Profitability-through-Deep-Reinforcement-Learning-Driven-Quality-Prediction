# %% [markdown]
# # Installation Requirements

# %%
# !pip uninstall --quiet tensorflow --yes
# !pip uninstall --quiet kapre --yes
# !pip install --quiet tensorflow==1.14.0
# !pip install --quiet stable_baselines
# !pip uninstall --quiet optuna --yes
# !pip install --quiet optuna==2.10.0
# !pip uninstall --quiet tensorboard-plugin-wit --yes
# !pip install --quiet "gym==0.19.0"
# Out:
#      |████████████████████████████████| 109.3 MB 45 kB/s
#      |████████████████████████████████| 50 kB 6.8 MB/s
#      |████████████████████████████████| 488 kB 54.6 MB/s
#      |████████████████████████████████| 3.1 MB 36.1 MB/s
#      |████████████████████████████████| 240 kB 5.0 MB/s
#      |████████████████████████████████| 18.3 MB 108 kB/s
#      |████████████████████████████████| 1.6 MB 42.6 MB/s
#      |████████████████████████████████| 308 kB 5.2 MB/s
#      |████████████████████████████████| 81 kB 9.7 MB/s
#      |████████████████████████████████| 209 kB 55.7 MB/s
#      |████████████████████████████████| 78 kB 7.3 MB/s
#      |████████████████████████████████| 49 kB 5.7 MB/s
#      |████████████████████████████████| 112 kB 50.3 MB/s
#      |████████████████████████████████| 147 kB 61.1 MB/s
# ...
#      |████████████████████████████████| 1.6 MB 5.1 MB/s
# ...

# %%
# Set working directory
# %cd /content/drive/MyDrive/ColabNotebooks/Masterarbeit/RLModel/src

# run config.py to load all required settings  
# %run config.py
# Out:
# /content/drive/MyDrive/ColabNotebooks/Masterarbeit/RLModel/src
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %% [markdown]
# # Optimize Sensitivity

# %%
# !python -W ignore hypertrain.py --path '../models/hypertuning/optimize_sens/' --study_name 'hyperstudy_sens' --timesteps 50000 --cross_validation 'sens' --save_every_x_steps 5000 --val_eval_freq 5000  --trials 30
# Out:
# Streaming output truncated to the last 5000 lines.
# [65.00%/100%] train_steps 32500 (eps 1881), mean_reward: -0.16 +/- 0.73, acc: 0.49, mean_timesteps: 23.94 +/- 53.46
# [66.00%/100%] train_steps 33000 (eps 1896), mean_reward: -0.18 +/- 0.76, acc: 0.48, mean_timesteps: 26.57 +/- 56.56
# [67.00%/100%] train_steps 33500 (eps 1908), mean_reward: -0.14 +/- 0.77, acc: 0.51, mean_timesteps: 27.95 +/- 57.33
# [68.00%/100%] train_steps 34000 (eps 1939), mean_reward: -0.11 +/- 0.75, acc: 0.53, mean_timesteps: 26.28 +/- 55.39
# [69.00%/100%] train_steps 34500 (eps 1955), mean_reward: -0.07 +/- 0.76, acc: 0.56, mean_timesteps: 23.99 +/- 53.94
# [70.00%/100%] train_steps 35000 (eps 1967), mean_reward: -0.05 +/- 0.77, acc: 0.60, mean_timesteps: 28.38 +/- 58.86
# save model...
# Evaluation on VALIDATION DATA - mean_reward: 0.37 +/- 0.43, acc: 0.84, mean_timesteps: 1.11 +/- 0.41, sens: 0.80
# ...

# %%
# !python -W ignore hypertrain.py --path '../models/hypertuning/optimize_sens/' --study_name 'hyperstudy_sens' --timesteps 50000 --cross_validation 'sens' --save_every_x_steps 5000 --val_eval_freq 5000  --trials 1 --enqueue_trial 11
# Out:
# Split_1
#
# ---------------------------------------------------------------------------------------
# Model Evaluation on TRAINING DATA (last 100 episodes)
# ---------------------------------------------------------------------------------------
# [1.00%/100%] train_steps 500 (eps 467), mean_reward: -0.05 +/- 0.48, acc: 0.22, mean_timesteps: 1.02 +/- 0.14
# [2.00%/100%] train_steps 1000 (eps 929), mean_reward: -0.05 +/- 0.49, acc: 0.21, mean_timesteps: 1.09 +/- 0.29
# [3.00%/100%] train_steps 1500 (eps 1391), mean_reward: 0.40 +/- 0.40, acc: 0.79, mean_timesteps: 1.07 +/- 0.26
# [4.00%/100%] train_steps 2000 (eps 1837), mean_reward: 0.39 +/- 0.43, acc: 0.76, mean_timesteps: 1.14 +/- 0.57
# [5.00%/100%] train_steps 2500 (eps 2189), mean_reward: 0.43 +/- 0.40, acc: 0.81, mean_timesteps: 1.41 +/- 0.71
# [6.00%/100%] train_steps 3000 (eps 2507), mean_reward: 0.35 +/- 0.40, acc: 0.75, mean_timesteps: 1.59 +/- 0.87
# ...

# %%
# !python -W ignore hypertrain.py --path '../models/hypertuning/optimize_sens/' --study_name 'hyperstudy_sens' --timesteps 50000 --cross_validation 'sens' --save_every_x_steps 5000 --val_eval_freq 5000 --trials 24 --optimize_again
# Out:
# Split_1
#
# ---------------------------------------------------------------------------------------
# Model Evaluation on TRAINING DATA (last 100 episodes)
# ---------------------------------------------------------------------------------------
# [1.00%/100%] train_steps 500 (eps 467), mean_reward: -0.05 +/- 0.48, acc: 0.22, mean_timesteps: 1.02 +/- 0.14
# [2.00%/100%] train_steps 1000 (eps 929), mean_reward: -0.05 +/- 0.49, acc: 0.21, mean_timesteps: 1.09 +/- 0.29
# [3.00%/100%] train_steps 1500 (eps 1391), mean_reward: 0.40 +/- 0.40, acc: 0.79, mean_timesteps: 1.07 +/- 0.26
# [4.00%/100%] train_steps 2000 (eps 1837), mean_reward: 0.39 +/- 0.43, acc: 0.76, mean_timesteps: 1.14 +/- 0.57
# [5.00%/100%] train_steps 2500 (eps 2189), mean_reward: 0.43 +/- 0.40, acc: 0.81, mean_timesteps: 1.41 +/- 0.71
# [6.00%/100%] train_steps 3000 (eps 2507), mean_reward: 0.35 +/- 0.40, acc: 0.75, mean_timesteps: 1.59 +/- 0.87
# ...

# %%
# !python -W ignore hypertrain.py --path '../models/hypertuning/optimize_sens/' --study_name 'hyperstudy_sens' --timesteps 50000 --cross_validation 'sens' --save_every_x_steps 5000 --val_eval_freq 5000  --trials 1 --enqueue_trial 19
# Out:
# Split_1
#
# ---------------------------------------------------------------------------------------
# Model Evaluation on TRAINING DATA (last 100 episodes)
# ---------------------------------------------------------------------------------------
# [1.00%/100%] train_steps 500 (eps 309), mean_reward: -0.32 +/- 0.74, acc: 0.44, mean_timesteps: 1.70 +/- 2.85
# [2.00%/100%] train_steps 1000 (eps 439), mean_reward: 0.11 +/- 0.46, acc: 0.79, mean_timesteps: 3.93 +/- 12.14
# [3.00%/100%] train_steps 1500 (eps 530), mean_reward: 0.09 +/- 0.47, acc: 0.80, mean_timesteps: 5.22 +/- 18.74
# [4.00%/100%] train_steps 2000 (eps 577), mean_reward: 0.07 +/- 0.50, acc: 0.77, mean_timesteps: 6.53 +/- 19.02
# [5.00%/100%] train_steps 2500 (eps 620), mean_reward: 0.13 +/- 0.47, acc: 0.81, mean_timesteps: 10.14 +/- 28.28
# [6.00%/100%] train_steps 3000 (eps 649), mean_reward: 0.09 +/- 0.50, acc: 0.77, mean_timesteps: 14.00 +/- 36.57
# ...

# %%
# !python -W ignore hypertrain.py --path '../models/hypertuning/optimize_sens/' --study_name 'hyperstudy_sens' --timesteps 50000 --cross_validation 'sens' --save_every_x_steps 5000 --val_eval_freq 5000 --trials 12 --optimize_again
# Out:
# Split_1
#
# ---------------------------------------------------------------------------------------
# Model Evaluation on TRAINING DATA (last 100 episodes)
# ---------------------------------------------------------------------------------------
# [1.00%/100%] train_steps 500 (eps 409), mean_reward: 0.12 +/- 0.53, acc: 0.50, mean_timesteps: 1.07 +/- 0.26
# [2.00%/100%] train_steps 1000 (eps 871), mean_reward: 0.09 +/- 0.52, acc: 0.47, mean_timesteps: 1.09 +/- 0.29
# [3.00%/100%] train_steps 1500 (eps 1339), mean_reward: 0.38 +/- 0.46, acc: 0.76, mean_timesteps: 1.07 +/- 0.26
# [4.00%/100%] train_steps 2000 (eps 1582), mean_reward: 0.27 +/- 0.46, acc: 0.72, mean_timesteps: 2.45 +/- 3.91
# [5.00%/100%] train_steps 2500 (eps 1945), mean_reward: 0.29 +/- 0.50, acc: 0.68, mean_timesteps: 1.28 +/- 0.75
# [6.00%/100%] train_steps 3000 (eps 2307), mean_reward: 0.36 +/- 0.47, acc: 0.75, mean_timesteps: 1.52 +/- 1.51
# ...

# %%
# !python -W ignore hypertrain.py --path '../models/hypertuning/optimize_sens/' --study_name 'hyperstudy_sens' --timesteps 50000 --cross_validation 'sens' --save_every_x_steps 5000 --val_eval_freq 5000  --trials 1 --enqueue_trial 30
# Out:
# Split_1
#
# ---------------------------------------------------------------------------------------
# Model Evaluation on TRAINING DATA (last 100 episodes)
# ---------------------------------------------------------------------------------------
# [1.00%/100%] train_steps 500 (eps 464), mean_reward: 0.43 +/- 0.82, acc: 0.70, mean_timesteps: 1.07 +/- 0.29
# [2.00%/100%] train_steps 1000 (eps 927), mean_reward: 0.37 +/- 0.83, acc: 0.67, mean_timesteps: 1.07 +/- 0.29
# [3.00%/100%] train_steps 1500 (eps 1400), mean_reward: 0.49 +/- 0.78, acc: 0.74, mean_timesteps: 1.08 +/- 0.31
# [4.00%/100%] train_steps 2000 (eps 1870), mean_reward: 0.62 +/- 0.68, acc: 0.82, mean_timesteps: 1.08 +/- 0.27
# [5.00%/100%] train_steps 2500 (eps 2334), mean_reward: 0.50 +/- 0.77, acc: 0.75, mean_timesteps: 1.09 +/- 0.32
# [6.00%/100%] train_steps 3000 (eps 2793), mean_reward: 0.48 +/- 0.79, acc: 0.73, mean_timesteps: 1.11 +/- 0.31
# ...

# %%
# !python -W ignore hypertrain.py --path '../models/hypertuning/optimize_sens/' --study_name 'hyperstudy_sens' --timesteps 50000 --cross_validation 'sens' --save_every_x_steps 5000 --val_eval_freq 5000 --trials 12 --optimize_again
# Out:
# Split_1
#
# ---------------------------------------------------------------------------------------
# Model Evaluation on TRAINING DATA (last 100 episodes)
# ---------------------------------------------------------------------------------------
# [1.00%/100%] train_steps 500 (eps 373), mean_reward: 0.12 +/- 0.67, acc: 0.41, mean_timesteps: 1.22 +/- 0.54
# [2.00%/100%] train_steps 1000 (eps 796), mean_reward: 0.19 +/- 0.71, acc: 0.45, mean_timesteps: 1.17 +/- 0.43
# [3.00%/100%] train_steps 1500 (eps 1232), mean_reward: 0.17 +/- 0.71, acc: 0.46, mean_timesteps: 1.22 +/- 0.48
# [4.00%/100%] train_steps 2000 (eps 1667), mean_reward: 0.09 +/- 0.67, acc: 0.39, mean_timesteps: 1.14 +/- 0.45
# [5.00%/100%] train_steps 2500 (eps 2093), mean_reward: 0.24 +/- 0.67, acc: 0.47, mean_timesteps: 1.14 +/- 0.40
# [6.00%/100%] train_steps 3000 (eps 2509), mean_reward: 0.17 +/- 0.67, acc: 0.42, mean_timesteps: 1.23 +/- 0.55
# ...

# %%
# !python -W ignore hypertrain.py --path '../models/hypertuning/optimize_sens/' --study_name 'hyperstudy_sens' --timesteps 50000 --cross_validation 'sens' --save_every_x_steps 5000 --val_eval_freq 5000  --trials 1 --enqueue_trial 41
# Out:
# Split_1
#
# ---------------------------------------------------------------------------------------
# Model Evaluation on TRAINING DATA (last 100 episodes)
# ---------------------------------------------------------------------------------------
# [1.00%/100%] train_steps 500 (eps 188), mean_reward: 0.19 +/- 0.82, acc: 0.65, mean_timesteps: 3.69 +/- 9.44
# [2.00%/100%] train_steps 1000 (eps 319), mean_reward: 0.19 +/- 0.84, acc: 0.65, mean_timesteps: 3.77 +/- 17.93
# [3.00%/100%] train_steps 1500 (eps 492), mean_reward: 0.51 +/- 0.62, acc: 0.83, mean_timesteps: 2.73 +/- 6.93
# [4.00%/100%] train_steps 2000 (eps 685), mean_reward: 0.42 +/- 0.68, acc: 0.77, mean_timesteps: 2.50 +/- 6.40
# [5.00%/100%] train_steps 2500 (eps 711), mean_reward: 0.35 +/- 0.75, acc: 0.74, mean_timesteps: 7.31 +/- 25.79
# [6.00%/100%] train_steps 3000 (eps 750), mean_reward: 0.39 +/- 0.74, acc: 0.77, mean_timesteps: 10.67 +/- 31.57
# ...

# %%
# !python -W ignore hypertrain.py --path '../models/hypertuning/optimize_sens/' --study_name 'hyperstudy_sens' --timesteps 50000 --cross_validation 'sens' --save_every_x_steps 5000 --val_eval_freq 5000 --trials 2 --optimize_again
# Out:
# Split_1
#
# ---------------------------------------------------------------------------------------
# Model Evaluation on TRAINING DATA (last 100 episodes)
# ---------------------------------------------------------------------------------------
# [1.00%/100%] train_steps 500 (eps 291), mean_reward: -0.08 +/- 0.39, acc: 0.34, mean_timesteps: 1.58 +/- 1.34
# [2.00%/100%] train_steps 1000 (eps 565), mean_reward: -0.10 +/- 0.39, acc: 0.30, mean_timesteps: 1.70 +/- 1.48
# [3.00%/100%] train_steps 1500 (eps 919), mean_reward: 0.21 +/- 0.47, acc: 0.73, mean_timesteps: 1.37 +/- 0.95
# [4.00%/100%] train_steps 2000 (eps 1114), mean_reward: 0.20 +/- 0.50, acc: 0.73, mean_timesteps: 2.81 +/- 4.58
# [5.00%/100%] train_steps 2500 (eps 1330), mean_reward: 0.25 +/- 0.40, acc: 0.77, mean_timesteps: 2.37 +/- 2.28
# [6.00%/100%] train_steps 3000 (eps 1547), mean_reward: 0.26 +/- 0.39, acc: 0.75, mean_timesteps: 2.42 +/- 2.18
# ...

# %%
# !python -W ignore hypertrain.py --path '../models/hypertuning/optimize_sens/' --study_name 'hyperstudy_sens' --timesteps 50000 --cross_validation 'sens' --save_every_x_steps 5000 --val_eval_freq 5000  --trials 1 --enqueue_trial 44
# Out:
# Split_1
#
# ---------------------------------------------------------------------------------------
# Model Evaluation on TRAINING DATA (last 100 episodes)
# ---------------------------------------------------------------------------------------
# [1.00%/100%] train_steps 500 (eps 446), mean_reward: 0.04 +/- 0.62, acc: 0.65, mean_timesteps: 1.09 +/- 0.32
# [2.00%/100%] train_steps 1000 (eps 881), mean_reward: 0.10 +/- 0.60, acc: 0.69, mean_timesteps: 1.16 +/- 0.42
# [3.00%/100%] train_steps 1500 (eps 1326), mean_reward: 0.04 +/- 0.62, acc: 0.65, mean_timesteps: 1.12 +/- 0.38
# [4.00%/100%] train_steps 2000 (eps 1768), mean_reward: 0.08 +/- 0.61, acc: 0.68, mean_timesteps: 1.12 +/- 0.35
# [5.00%/100%] train_steps 2500 (eps 2140), mean_reward: 0.20 +/- 0.55, acc: 0.77, mean_timesteps: 1.23 +/- 0.76
# [6.00%/100%] train_steps 3000 (eps 2372), mean_reward: 0.15 +/- 0.58, acc: 0.73, mean_timesteps: 2.41 +/- 3.56
# ...

# %%
import optuna
study_name = 'hyperstudy_sens'
storage_name = "sqlite:///{}.db".format(study_name)

study = optuna.load_study(study_name=study_name, storage=storage_name)
study.trials_dataframe(attrs=("number", "value", "params", "state"))
# Out:
#     number     value  params_batch_size  params_buffer_size  params_double_q  \
# 0        0  0.479885                 32               30000             True
# 1        1  0.823563                128               50000             True
# 2        2  0.672989                128               20000            False
# 3        3  0.689080                128                5000             True
# 4        4  0.983046                 32               40000            False
# 5        5  0.404598                 64                5000            False
# 6        6  0.597989                128                5000            False
# 7        7  0.739368                 64               40000            False
# 8        8  0.738793                 32                5000            False
# 9        9  0.673276                128               10000            False
# 10      10  0.856609                 32               40000             True
# ...
