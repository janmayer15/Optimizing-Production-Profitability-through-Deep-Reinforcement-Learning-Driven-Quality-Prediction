# %% [markdown]
# # Installation Requirements

# %%
# !pip uninstall --quiet tensorflow --yes
# !pip uninstall --quiet kapre --yes
# !pip install --quiet tensorflow==1.14.0
# !pip install --quiet stable_baselines
# !pip uninstall --quiet optuna --yes
# !pip install --quiet optuna==2.10.0
# !pip uninstall --quiet tensorboard-plugin-wit --yes
# !pip install --quiet "gym==0.19.0"
# Out:
#      |████████████████████████████████| 109.3 MB 46 kB/s
#      |████████████████████████████████| 488 kB 53.6 MB/s
#      |████████████████████████████████| 3.1 MB 51.1 MB/s
#      |████████████████████████████████| 50 kB 4.9 MB/s
#      |████████████████████████████████| 240 kB 5.2 MB/s
#      |████████████████████████████████| 18.3 MB 84 kB/s
#      |████████████████████████████████| 1.6 MB 54.6 MB/s
# WARNING: Skipping optuna as it is not installed.
#      |████████████████████████████████| 308 kB 5.2 MB/s
#      |████████████████████████████████| 209 kB 51.5 MB/s
#      |████████████████████████████████| 81 kB 8.3 MB/s
#      |████████████████████████████████| 78 kB 6.4 MB/s
#      |████████████████████████████████| 147 kB 51.9 MB/s
#      |████████████████████████████████| 112 kB 77.6 MB/s
#      |████████████████████████████████| 49 kB 5.5 MB/s
# ...
#      |████████████████████████████████| 1.6 MB 5.1 MB/s
# ...

# %%
# Set working directory
# %cd /content/drive/MyDrive/ColabNotebooks/Masterarbeit/RLModel/src

# run config.py to load all required settings  
# %run config.py
# Out:
# /content/drive/MyDrive/ColabNotebooks/Masterarbeit/RLModel/src
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %% [markdown]
# # Optimize Accuracy

# %%
# !python -W ignore hypertrain.py --path '../models/hypertuning/optimize_acc_new/' --study_name 'hyperstudy_acc_new' --timesteps 50000 --cross_validation 'acc' --save_every_x_steps 5000 --val_eval_freq 5000  --trials 40
# Out:
# Streaming output truncated to the last 5000 lines.
# [82.00%/100%] train_steps 41000 (eps 20940), mean_reward: 0.71 +/- 0.63, acc: 0.86, mean_timesteps: 1.33 +/- 1.14
# [83.00%/100%] train_steps 41500 (eps 21206), mean_reward: 0.70 +/- 0.58, acc: 0.88, mean_timesteps: 2.25 +/- 2.84
# [84.00%/100%] train_steps 42000 (eps 21511), mean_reward: 0.72 +/- 0.54, acc: 0.89, mean_timesteps: 1.93 +/- 2.69
# [85.00%/100%] train_steps 42500 (eps 21739), mean_reward: 0.70 +/- 0.61, acc: 0.86, mean_timesteps: 2.16 +/- 3.01
# [86.00%/100%] train_steps 43000 (eps 22051), mean_reward: 0.64 +/- 0.66, acc: 0.85, mean_timesteps: 1.39 +/- 1.22
# [87.00%/100%] train_steps 43500 (eps 22329), mean_reward: 0.61 +/- 0.64, acc: 0.79, mean_timesteps: 1.91 +/- 2.38
# [88.00%/100%] train_steps 44000 (eps 22619), mean_reward: 0.67 +/- 0.68, acc: 0.86, mean_timesteps: 1.88 +/- 2.59
# [89.00%/100%] train_steps 44500 (eps 22888), mean_reward: 0.75 +/- 0.53, acc: 0.87, mean_timesteps: 1.76 +/- 2.14
# ...

# %%
# !python -W ignore hypertrain.py --path '../models/hypertuning/optimize_acc_new/' --study_name 'hyperstudy_acc_new' --timesteps 50000 --cross_validation 'acc' --save_every_x_steps 5000 --val_eval_freq 5000  --trials 1 --enqueue_trial 10
# Out:
# Split_1
#
# ---------------------------------------------------------------------------------------
# Model Evaluation on TRAINING DATA (last 100 episodes)
# ---------------------------------------------------------------------------------------
# [1.00%/100%] train_steps 500 (eps 477), mean_reward: -0.49 +/- 0.68, acc: 0.17, mean_timesteps: 1.02 +/- 0.14
# [2.00%/100%] train_steps 1000 (eps 956), mean_reward: -0.39 +/- 0.74, acc: 0.22, mean_timesteps: 1.05 +/- 0.22
# [3.00%/100%] train_steps 1500 (eps 1435), mean_reward: -0.38 +/- 0.76, acc: 0.23, mean_timesteps: 1.05 +/- 0.22
# [4.00%/100%] train_steps 2000 (eps 1917), mean_reward: -0.35 +/- 0.78, acc: 0.25, mean_timesteps: 1.02 +/- 0.14
# [5.00%/100%] train_steps 2500 (eps 2399), mean_reward: -0.45 +/- 0.71, acc: 0.19, mean_timesteps: 1.02 +/- 0.20
# [6.00%/100%] train_steps 3000 (eps 2879), mean_reward: -0.36 +/- 0.77, acc: 0.24, mean_timesteps: 1.06 +/- 0.28
# ...

# %%
# !python -W ignore hypertrain.py --path '../models/hypertuning/optimize_acc_new/' --study_name 'hyperstudy_acc_new' --timesteps 50000 --cross_validation 'acc' --save_every_x_steps 5000 --val_eval_freq 5000  --trials 30 --optimize_again
# Out:
# Split_1
#
# ---------------------------------------------------------------------------------------
# Model Evaluation on TRAINING DATA (last 100 episodes)
# ---------------------------------------------------------------------------------------
# [1.00%/100%] train_steps 500 (eps 439), mean_reward: 0.41 +/- 0.79, acc: 0.65, mean_timesteps: 1.10 +/- 0.33
# [2.00%/100%] train_steps 1000 (eps 848), mean_reward: 0.56 +/- 0.71, acc: 0.75, mean_timesteps: 1.27 +/- 0.58
# [3.00%/100%] train_steps 1500 (eps 1036), mean_reward: 0.57 +/- 0.71, acc: 0.75, mean_timesteps: 2.49 +/- 2.31
# [4.00%/100%] train_steps 2000 (eps 1245), mean_reward: 0.43 +/- 0.80, acc: 0.69, mean_timesteps: 2.48 +/- 2.84
# [5.00%/100%] train_steps 2500 (eps 1399), mean_reward: 0.42 +/- 0.74, acc: 0.67, mean_timesteps: 3.03 +/- 2.36
# [6.00%/100%] train_steps 3000 (eps 1564), mean_reward: 0.46 +/- 0.74, acc: 0.69, mean_timesteps: 3.53 +/- 3.44
# ...

# %%
# !python -W ignore hypertrain.py --path '../models/hypertuning/optimize_acc_new/' --study_name 'hyperstudy_acc_new' --timesteps 50000 --cross_validation 'acc' --save_every_x_steps 5000 --val_eval_freq 5000  --trials 1 --enqueue_trial 19
# Out:
# Split_1
#
# ---------------------------------------------------------------------------------------
# Model Evaluation on TRAINING DATA (last 100 episodes)
# ---------------------------------------------------------------------------------------
# [1.00%/100%] train_steps 500 (eps 317), mean_reward: -0.10 +/- 0.62, acc: 0.38, mean_timesteps: 2.38 +/- 5.55
# [2.00%/100%] train_steps 1000 (eps 434), mean_reward: -0.15 +/- 0.62, acc: 0.34, mean_timesteps: 4.03 +/- 17.93
# [3.00%/100%] train_steps 1500 (eps 574), mean_reward: -0.27 +/- 0.53, acc: 0.22, mean_timesteps: 2.24 +/- 8.60
# [4.00%/100%] train_steps 2000 (eps 716), mean_reward: -0.13 +/- 0.64, acc: 0.34, mean_timesteps: 2.75 +/- 6.77
# [5.00%/100%] train_steps 2500 (eps 802), mean_reward: -0.14 +/- 0.64, acc: 0.34, mean_timesteps: 5.30 +/- 24.58
# [6.00%/100%] train_steps 3000 (eps 944), mean_reward: -0.20 +/- 0.58, acc: 0.29, mean_timesteps: 2.01 +/- 3.39
# ...

# %%
# !python -W ignore hypertrain.py --path '../models/hypertuning/optimize_acc_new/' --study_name 'hyperstudy_acc_new' --timesteps 50000 --cross_validation 'acc' --save_every_x_steps 5000 --val_eval_freq 5000  --trials 20 --optimize_again
# Out:
# Split_1
#
# ---------------------------------------------------------------------------------------
# Model Evaluation on TRAINING DATA (last 100 episodes)
# ---------------------------------------------------------------------------------------
# [1.00%/100%] train_steps 500 (eps 392), mean_reward: -0.00 +/- 0.84, acc: 0.49, mean_timesteps: 1.10 +/- 0.36
# [2.00%/100%] train_steps 1000 (eps 835), mean_reward: 0.49 +/- 0.80, acc: 0.73, mean_timesteps: 1.16 +/- 0.88
# [3.00%/100%] train_steps 1500 (eps 1107), mean_reward: 0.67 +/- 0.68, acc: 0.83, mean_timesteps: 1.76 +/- 1.37
# [4.00%/100%] train_steps 2000 (eps 1232), mean_reward: 0.27 +/- 0.88, acc: 0.60, mean_timesteps: 4.28 +/- 4.91
# [5.00%/100%] train_steps 2500 (eps 1342), mean_reward: 0.24 +/- 0.85, acc: 0.61, mean_timesteps: 4.73 +/- 4.85
# [6.00%/100%] train_steps 3000 (eps 1475), mean_reward: 0.46 +/- 0.81, acc: 0.71, mean_timesteps: 3.43 +/- 4.50
# ...

# %%
# !python -W ignore hypertrain.py --path '../models/hypertuning/optimize_acc_new/' --study_name 'hyperstudy_acc_new' --timesteps 50000 --cross_validation 'acc' --save_every_x_steps 5000 --val_eval_freq 5000  --trials 1 --enqueue_trial 28
# Out:
# Split_1
#
# ---------------------------------------------------------------------------------------
# Model Evaluation on TRAINING DATA (last 100 episodes)
# ---------------------------------------------------------------------------------------
# [1.00%/100%] train_steps 500 (eps 335), mean_reward: 0.42 +/- 0.77, acc: 0.66, mean_timesteps: 1.98 +/- 5.56
# [2.00%/100%] train_steps 1000 (eps 508), mean_reward: 0.45 +/- 0.67, acc: 0.62, mean_timesteps: 1.55 +/- 3.04
# [3.00%/100%] train_steps 1500 (eps 579), mean_reward: 0.22 +/- 1.41, acc: 0.59, mean_timesteps: 5.77 +/- 24.79
# [4.00%/100%] train_steps 2000 (eps 733), mean_reward: 0.28 +/- 0.77, acc: 0.54, mean_timesteps: 1.44 +/- 1.81
# [5.00%/100%] train_steps 2500 (eps 956), mean_reward: 0.31 +/- 0.76, acc: 0.55, mean_timesteps: 1.86 +/- 4.49
# [6.00%/100%] train_steps 3000 (eps 1251), mean_reward: 0.31 +/- 0.78, acc: 0.56, mean_timesteps: 1.37 +/- 1.32
# ...

# %%
# !python -W ignore hypertrain.py --path '../models/hypertuning/optimize_acc_new/' --study_name 'hyperstudy_acc_new' --timesteps 50000 --cross_validation 'acc' --save_every_x_steps 5000 --val_eval_freq 5000  --trials 14 --optimize_again
# Out:
# Split_1
#
# ---------------------------------------------------------------------------------------
# Model Evaluation on TRAINING DATA (last 100 episodes)
# ---------------------------------------------------------------------------------------
# [1.00%/100%] train_steps 500 (eps 473), mean_reward: 0.61 +/- 0.70, acc: 0.76, mean_timesteps: 1.10 +/- 0.48
# [2.00%/100%] train_steps 1000 (eps 929), mean_reward: 0.51 +/- 0.75, acc: 0.70, mean_timesteps: 1.09 +/- 0.35
# [3.00%/100%] train_steps 1500 (eps 1384), mean_reward: 0.58 +/- 0.73, acc: 0.75, mean_timesteps: 1.10 +/- 0.33
# [4.00%/100%] train_steps 2000 (eps 1839), mean_reward: 0.39 +/- 0.81, acc: 0.63, mean_timesteps: 1.07 +/- 0.29
# [5.00%/100%] train_steps 2500 (eps 2304), mean_reward: 0.50 +/- 0.76, acc: 0.70, mean_timesteps: 1.09 +/- 0.45
# [6.00%/100%] train_steps 3000 (eps 2775), mean_reward: 0.41 +/- 0.78, acc: 0.64, mean_timesteps: 1.06 +/- 0.42
# ...

# %%
# !python -W ignore hypertrain.py --path '../models/hypertuning/optimize_acc_new/' --study_name 'hyperstudy_acc_new' --timesteps 50000 --cross_validation 'acc' --save_every_x_steps 5000 --val_eval_freq 5000  --trials 1 --enqueue_trial 31
# Out:
# Split_1
#
# ---------------------------------------------------------------------------------------
# Model Evaluation on TRAINING DATA (last 100 episodes)
# ---------------------------------------------------------------------------------------
# [1.00%/100%] train_steps 500 (eps 364), mean_reward: 0.33 +/- 0.76, acc: 0.56, mean_timesteps: 2.13 +/- 6.54
# [2.00%/100%] train_steps 1000 (eps 508), mean_reward: 0.45 +/- 0.69, acc: 0.61, mean_timesteps: 1.50 +/- 3.05
# [3.00%/100%] train_steps 1500 (eps 579), mean_reward: 0.35 +/- 0.71, acc: 0.55, mean_timesteps: 5.60 +/- 24.75
# [4.00%/100%] train_steps 2000 (eps 734), mean_reward: 0.27 +/- 0.78, acc: 0.53, mean_timesteps: 3.53 +/- 17.86
# [5.00%/100%] train_steps 2500 (eps 1026), mean_reward: 0.48 +/- 0.72, acc: 0.65, mean_timesteps: 1.72 +/- 2.19
# [6.00%/100%] train_steps 3000 (eps 1257), mean_reward: 0.29 +/- 0.81, acc: 0.55, mean_timesteps: 2.99 +/- 17.40
# ...

# %%
# !python -W ignore hypertrain.py --path '../models/hypertuning/optimize_acc_new/' --study_name 'hyperstudy_acc_new' --timesteps 50000 --cross_validation 'acc' --save_every_x_steps 5000 --val_eval_freq 5000  --trials 12 --optimize_again
# Out:
# Split_1
#
# ---------------------------------------------------------------------------------------
# Model Evaluation on TRAINING DATA (last 100 episodes)
# ---------------------------------------------------------------------------------------
# [1.00%/100%] train_steps 500 (eps 326), mean_reward: 0.39 +/- 0.76, acc: 0.62, mean_timesteps: 1.79 +/- 3.48
# [2.00%/100%] train_steps 1000 (eps 702), mean_reward: 0.46 +/- 0.83, acc: 0.70, mean_timesteps: 1.33 +/- 0.88
# [3.00%/100%] train_steps 1500 (eps 1017), mean_reward: 0.67 +/- 0.68, acc: 0.81, mean_timesteps: 1.50 +/- 2.10
# [4.00%/100%] train_steps 2000 (eps 1285), mean_reward: 0.59 +/- 0.75, acc: 0.79, mean_timesteps: 1.96 +/- 2.88
# [5.00%/100%] train_steps 2500 (eps 1570), mean_reward: 0.70 +/- 0.67, acc: 0.83, mean_timesteps: 1.61 +/- 2.18
# [6.00%/100%] train_steps 3000 (eps 1843), mean_reward: 0.51 +/- 0.81, acc: 0.74, mean_timesteps: 1.65 +/- 3.47
# ...

# %%
# !python -W ignore hypertrain.py --path '../models/hypertuning/optimize_acc_new/' --study_name 'hyperstudy_acc_new' --timesteps 50000 --cross_validation 'acc' --save_every_x_steps 5000 --val_eval_freq 5000  --trials 1 --enqueue_trial 42
# Out:
# Split_1
#
# ---------------------------------------------------------------------------------------
# Model Evaluation on TRAINING DATA (last 100 episodes)
# ---------------------------------------------------------------------------------------
# [1.00%/100%] train_steps 500 (eps 460), mean_reward: 0.34 +/- 0.65, acc: 0.65, mean_timesteps: 1.13 +/- 0.44
# [2.00%/100%] train_steps 1000 (eps 664), mean_reward: 0.23 +/- 0.67, acc: 0.56, mean_timesteps: 1.17 +/- 0.55
# [3.00%/100%] train_steps 1500 (eps 736), mean_reward: 0.29 +/- 0.69, acc: 0.63, mean_timesteps: 4.67 +/- 24.48
# [4.00%/100%] train_steps 2000 (eps 748), mean_reward: 0.28 +/- 0.72, acc: 0.63, mean_timesteps: 9.97 +/- 38.10
# [5.00%/100%] train_steps 2500 (eps 762), mean_reward: 0.27 +/- 0.74, acc: 0.64, mean_timesteps: 13.47 +/- 44.60
# [6.00%/100%] train_steps 3000 (eps 767), mean_reward: 0.26 +/- 0.76, acc: 0.64, mean_timesteps: 18.72 +/- 52.43
# ...

# %%
# !python -W ignore hypertrain.py --path '../models/hypertuning/optimize_acc_new/' --study_name 'hyperstudy_acc_new' --timesteps 50000 --cross_validation 'acc' --save_every_x_steps 5000 --val_eval_freq 5000  --trials 2 --optimize_again
# Out:
# Split_1
#
# ---------------------------------------------------------------------------------------
# Model Evaluation on TRAINING DATA (last 100 episodes)
# ---------------------------------------------------------------------------------------
# [1.00%/100%] train_steps 500 (eps 474), mean_reward: 0.46 +/- 0.83, acc: 0.71, mean_timesteps: 1.09 +/- 0.38
# [2.00%/100%] train_steps 1000 (eps 920), mean_reward: 0.57 +/- 0.73, acc: 0.76, mean_timesteps: 1.05 +/- 0.22
# [3.00%/100%] train_steps 1500 (eps 1397), mean_reward: 0.36 +/- 0.85, acc: 0.65, mean_timesteps: 1.07 +/- 0.29
# [4.00%/100%] train_steps 2000 (eps 1863), mean_reward: 0.48 +/- 0.78, acc: 0.70, mean_timesteps: 1.03 +/- 0.17
# [5.00%/100%] train_steps 2500 (eps 2268), mean_reward: 0.55 +/- 0.73, acc: 0.74, mean_timesteps: 1.12 +/- 0.43
# [6.00%/100%] train_steps 3000 (eps 2483), mean_reward: 0.62 +/- 0.71, acc: 0.78, mean_timesteps: 3.07 +/- 17.40
# ...

# %%
import optuna
study_name = 'hyperstudy_acc_new'
storage_name = "sqlite:///{}.db".format(study_name)

study = optuna.load_study(study_name=study_name, storage=storage_name)
study.trials_dataframe(attrs=("number", "value", "params", "state"))
# Out:
#     number     value  params_batch_size  params_buffer_size  params_double_q  \
# 0        0  0.858641                 32               30000             True
# 1        1  0.870388                128               50000             True
# 2        2  0.885129                128               20000            False
# 3        3  0.873321                128                5000             True
# 4        4  0.610947                 32               40000            False
# 5        5  0.842430                 64                5000            False
# 6        6  0.864514                128                5000            False
# 7        7  0.863026                 64               40000            False
# 8        8  0.833562                 32                5000            False
# 9        9  0.874826                128               10000            False
# 10      10       NaN                128               20000             True
# ...
