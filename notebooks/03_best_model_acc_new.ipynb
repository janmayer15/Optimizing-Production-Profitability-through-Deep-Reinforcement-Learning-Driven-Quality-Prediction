# %% [markdown]
# # Installation Requirements

# %%
# !pip uninstall --quiet tensorflow --yes
# !pip uninstall --quiet kapre --yes
# !pip install --quiet tensorflow==1.14.0
# !pip install --quiet stable_baselines
# !pip uninstall --quiet optuna --yes
# !pip install --quiet optuna==2.10.0
# !pip uninstall --quiet tensorboard-plugin-wit --yes
# !pip install --quiet "gym==0.19.0"
# Out:
#      |████████████████████████████████| 109.3 MB 54 kB/s
#      |████████████████████████████████| 3.1 MB 38.7 MB/s
#      |████████████████████████████████| 488 kB 62.1 MB/s
#      |████████████████████████████████| 50 kB 5.6 MB/s
#      |████████████████████████████████| 240 kB 7.7 MB/s
#      |████████████████████████████████| 18.3 MB 110 kB/s
#      |████████████████████████████████| 1.6 MB 32.4 MB/s
# WARNING: Skipping optuna as it is not installed.
#      |████████████████████████████████| 308 kB 8.3 MB/s
#      |████████████████████████████████| 209 kB 66.3 MB/s
#      |████████████████████████████████| 81 kB 9.1 MB/s
#      |████████████████████████████████| 78 kB 6.2 MB/s
#      |████████████████████████████████| 147 kB 61.9 MB/s
#      |████████████████████████████████| 49 kB 5.2 MB/s
#      |████████████████████████████████| 112 kB 52.2 MB/s
# ...
#      |████████████████████████████████| 1.6 MB 9.0 MB/s
# ...

# %%
# Set working directory
# %cd /content/drive/MyDrive/ColabNotebooks/Masterarbeit/RLModel/src

# run config.py to load all required settings  
# %run config.py
# Out:
# /content/drive/MyDrive/ColabNotebooks/Masterarbeit/RLModel/src
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %% [markdown]
# # Analyze Hypertuning

# %%
import optuna
study_name = 'hyperstudy_acc_new'
storage_name = "sqlite:///{}.db".format(study_name)

study = optuna.load_study(study_name=study_name, storage=storage_name)
study.trials_dataframe(attrs=("number", "value", "params", "state"))
# Out:
#     number     value  params_batch_size  params_buffer_size  params_double_q  \
# 0        0  0.858641                 32               30000             True
# 1        1  0.870388                128               50000             True
# 2        2  0.885129                128               20000            False
# 3        3  0.873321                128                5000             True
# 4        4  0.610947                 32               40000            False
# 5        5  0.842430                 64                5000            False
# 6        6  0.864514                128                5000            False
# 7        7  0.863026                 64               40000            False
# 8        8  0.833562                 32                5000            False
# 9        9  0.874826                128               10000            False
# 10      10       NaN                128               20000             True
# ...

# %%
from optuna.visualization import plot_param_importances
plot_param_importances(study)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Conclusion
# trial 2 reaches the best acc
# - 1.Fold: 5.000 training steps
# - 2.Fold: 20.000 training steps
# - 3.Fold: 10.000 training steps
# - 4.Fold: 40.000 training steps
#
# --> Training on all training data with a training steps length of mean(5,20,10,40) = 18.750

# %% [markdown]
# # Train best model

# %%
# !python -W ignore train.py --path '../models/best_models/best_model_acc_new/' --study_name 'hyperstudy_acc_new' --timesteps 18750 --custom_callback --train_best_hypermodel
# Out:
# ---------------------------------------------------------------------------------------
# Model Evaluation on TRAINING DATA (last 100 episodes)
# ---------------------------------------------------------------------------------------
# [2.67%/100%] train_steps 500 (eps 475), mean_reward: -0.45 +/- 0.68, acc: 0.22, mean_timesteps: 1.05 +/- 0.22
# [5.33%/100%] train_steps 1000 (eps 951), mean_reward: -0.43 +/- 0.69, acc: 0.23, mean_timesteps: 1.05 +/- 0.26
# [8.00%/100%] train_steps 1500 (eps 1434), mean_reward: -0.50 +/- 0.64, acc: 0.18, mean_timesteps: 1.04 +/- 0.20
# [10.67%/100%] train_steps 2000 (eps 1913), mean_reward: -0.46 +/- 0.66, acc: 0.21, mean_timesteps: 1.07 +/- 0.26
# [13.33%/100%] train_steps 2500 (eps 2388), mean_reward: -0.46 +/- 0.67, acc: 0.21, mean_timesteps: 1.08 +/- 0.31
# [16.00%/100%] train_steps 3000 (eps 2858), mean_reward: -0.43 +/- 0.69, acc: 0.23, mean_timesteps: 1.04 +/- 0.20
# ...

# %%
# !python -W ignore evaluate.py --path '../models/best_models/best_model_acc_new/' --study_name 'hyperstudy_acc_new' --train_best_hypermodel --evaluation_summary
# Out:
# Evaluation Summary on Test_Data ( 292 data points)
#                 model  mean_reward      acc  sensitivity  precision        f1  specificity        gm  mean_timesteps  mean_timesteps_good  mean_timesteps_bad best_mean_reward best_f1 best_sensitivity best_specificity best_acc best_gm
# 0  rl_model_final.zip     0.697643  0.85274     0.470588        0.6  0.527473      0.93361  0.662832        1.986301             2.003968               1.875                x       x                x                x        x       x
#
# Evaluation Summary on Train_Data ( 679 data points)
#                 model  mean_reward       acc  sensitivity  precision        f1  specificity        gm  mean_timesteps  mean_timesteps_good  mean_timesteps_bad best_mean_reward best_f1 best_sensitivity best_specificity best_acc best_gm
# ...
