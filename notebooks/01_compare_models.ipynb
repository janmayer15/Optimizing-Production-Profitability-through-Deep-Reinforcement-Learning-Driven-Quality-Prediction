# %% [markdown]
# # Installation Requirements

# %%
# !pip uninstall --quiet tensorflow --yes
# !pip uninstall --quiet kapre --yes
# !pip install --quiet tensorflow==1.14.0
# !pip install --quiet stable_baselines
# !pip uninstall --quiet optuna --yes
# !pip install --quiet optuna==2.10.0
# !pip uninstall --quiet tensorboard-plugin-wit --yes
# !pip install --quiet "gym==0.19.0"
# Out:
#      |████████████████████████████████| 109.3 MB 47 kB/s
#      |████████████████████████████████| 50 kB 5.9 MB/s
#      |████████████████████████████████| 3.1 MB 45.6 MB/s
#      |████████████████████████████████| 488 kB 54.2 MB/s
#      |████████████████████████████████| 240 kB 4.5 MB/s
#      |████████████████████████████████| 1.6 MB 42.8 MB/s
#      |████████████████████████████████| 18.3 MB 42.8 MB/s
# WARNING: Skipping optuna as it is not installed.
#      |████████████████████████████████| 308 kB 5.1 MB/s
#      |████████████████████████████████| 209 kB 60.9 MB/s
#      |████████████████████████████████| 81 kB 8.3 MB/s
#      |████████████████████████████████| 78 kB 6.0 MB/s
#      |████████████████████████████████| 147 kB 71.0 MB/s
#      |████████████████████████████████| 49 kB 5.5 MB/s
#      |████████████████████████████████| 112 kB 59.9 MB/s
# ...
#      |████████████████████████████████| 1.6 MB 5.0 MB/s
# ...

# %%
# Set working directory
# %cd /content/drive/MyDrive/ColabNotebooks/Masterarbeit/RLModel/src

# run config.py to load all required settings  
# %run config.py
# Out:
# /content/drive/MyDrive/ColabNotebooks/Masterarbeit/RLModel/src
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %% [markdown]
# # Console Commands

# %% [markdown]
# *   Training - **train.py**
#
# ```
# Normal training with different callbacks
# !python -W ignore train.py --path '../models/folder/' --timesteps 50000 (no callback will be printed)
# !python -W ignore train.py --path '../models/folder/' --timesteps 50000 --standard_callback
# !python -W ignore train.py --path '../models/folder/' --timesteps 50000 --custom_callback
#                                                                         --train_eval_n_episodes (default 100)
#                                                                         --train_eval_freq (default 500)
#                                                                         --save_every_x_steps (default 0)
#
# Cross-Validation training with fixed callback
# !python -W ignore train.py --path '../models/folder/' --timesteps 50000 --cross_validation ('f1','acc','sens','spez')
#                                                                         --early_stopping (default 0)
#                                                                         --save_every_x_steps (default 5000)
#                                                                         --train_eval_freq (default 500)
#                                                                         --val_eval_freq (default 5000)
#
# Change hyperparameters
# !python -W ignore train.py --path '../models/folder/' --timesteps 50000 (--CALLBACK ARGUMENTS or CROSSVALIDATION ARGUMENTS above)
#                                                                         --double_q
#                                                                         --layer_normalization
#                                                                         --dueling
#                                                                         --pos_reward_good_wafer (default '1.0')
#                                                                         --neg_reward_good_wafer (default '1.0')
#                                                                         --pos_reward_bad_wafer (default '1.0')
#                                                                         --neg_reward_bad_wafer (default '1.0')
#                                                                         --discount_wait (default '0.001')
#                                                                         --buffer_size_replay (default 50000)
#                                                                         --prioritized_replay
#
# ```
# *   Hyperparameter Tuning - **hypertrain.py**
#
# ```
# !python -W ignore hypertrain.py --path '../models/folder/' --timesteps 100 --cross_validation ('f1','acc','sens','spez')
#                                                                             --early_stopping (default 0)
#                                                                             --study_name
#                                                                             --trials (default 5)
# ```
# *   Evaluation - **evaluate.py**
#
# ```
# !python -W ignore evaluate.py --path '../models/folder/'
# !python -W ignore evaluate.py --path '../models/folder/' --evaluate_on_test
# !python -W ignore evaluate.py --path '../models/folder/' --evaluate_on_train
# ```
# *   Plotting Training Curve
#
# ```
# %run plot.py --path '../models/folder/' --smoothing 100
# ```

# %% [markdown]
# # Experiment: Nur 1 Hyperparameter wird geändert

# %% [markdown]
# ## Model 0a (100.000 timesteps)

# %%
# !python -W ignore train.py --path '../models/model_comparison/model_0a/' --timesteps 100000 --custom_callback --save_every_x_steps 5000
# Out:
# ---------------------------------------------------------------------------------------
# Model Evaluation on TRAINING DATA (last 100 episodes)
# ---------------------------------------------------------------------------------------
# [0.50%/100%] train_steps 500 (eps 344), mean_reward: 0.02 +/- 1.00, acc: 0.51, mean_timesteps: 1.45 +/- 0.80
# [1.00%/100%] train_steps 1000 (eps 684), mean_reward: 0.08 +/- 1.00, acc: 0.54, mean_timesteps: 1.50 +/- 0.82
# [1.50%/100%] train_steps 1500 (eps 1056), mean_reward: 0.10 +/- 0.99, acc: 0.55, mean_timesteps: 1.26 +/- 0.63
# [2.00%/100%] train_steps 2000 (eps 1363), mean_reward: 0.16 +/- 0.99, acc: 0.58, mean_timesteps: 1.49 +/- 0.79
# [2.50%/100%] train_steps 2500 (eps 1655), mean_reward: 0.16 +/- 0.99, acc: 0.58, mean_timesteps: 1.62 +/- 0.95
# [3.00%/100%] train_steps 3000 (eps 1916), mean_reward: 0.16 +/- 0.99, acc: 0.58, mean_timesteps: 1.91 +/- 1.11
# ...

# %%
# !python -W ignore evaluate.py --path '../models/model_comparison/model_0a/' --evaluation_summary
# Out:
# test
# Evaluation Summary on Test_Data ( 292 data points)
#                         model  mean_reward       acc  sensitivity  precision        f1  specificity        gm  mean_timesteps  mean_timesteps_good  mean_timesteps_bad best_mean_reward best_f1 best_sensitivity best_specificity best_acc best_gm
# 0     rl_model_5000_steps.zip     0.189423  0.691781     0.725490   0.445783  0.552239     0.809129  0.766169       48.342466            36.203320          105.705882                                         x
# 1    rl_model_10000_steps.zip    -1.553348  0.058219     1.000000   0.174658  0.297376     0.000000  0.000000      160.561644           169.070539          120.352941                                         x
# 2    rl_model_15000_steps.zip     0.622665  0.828767     0.098039   0.555556  0.166667     0.983402  0.310503       16.544521            15.908714           19.549020                                                          x
# ...

# %%
# %run plot.py --path '../models/model_comparison/model_0a/' --smoothing 1000

# %% [markdown]
# ## Model 0b (200.000 timesteps)

# %%
# !python -W ignore train.py --path '../models/model_comparison/model_0b/' --timesteps 200000 --custom_callback --save_every_x_steps 5000
# Out:
# ---------------------------------------------------------------------------------------
# Model Evaluation on TRAINING DATA (last 100 episodes)
# ---------------------------------------------------------------------------------------
# [0.25%/100%] train_steps 500 (eps 343), mean_reward: -0.02 +/- 1.00, acc: 0.49, mean_timesteps: 1.46 +/- 0.81
# [0.50%/100%] train_steps 1000 (eps 682), mean_reward: 0.04 +/- 1.00, acc: 0.52, mean_timesteps: 1.50 +/- 0.82
# [0.75%/100%] train_steps 1500 (eps 1038), mean_reward: 0.30 +/- 0.95, acc: 0.65, mean_timesteps: 1.35 +/- 0.74
# [1.00%/100%] train_steps 2000 (eps 1355), mean_reward: 0.18 +/- 0.98, acc: 0.59, mean_timesteps: 1.54 +/- 0.89
# [1.25%/100%] train_steps 2500 (eps 1672), mean_reward: -0.00 +/- 1.00, acc: 0.50, mean_timesteps: 1.54 +/- 0.89
# [1.50%/100%] train_steps 3000 (eps 1977), mean_reward: 0.12 +/- 0.99, acc: 0.56, mean_timesteps: 1.72 +/- 0.99
# ...

# %%
# !python -W ignore evaluate.py --path '../models/model_comparison/model_0b/'
# Out:
# Evaluation Summary on  Test_Data  ( 292  data points )
#                         model  mean_reward       acc  sensitivity  precision        f1  specificity  mean_timesteps  mean_timesteps_good  mean_timesteps_bad best_mean_reward best_f1 best_sensitivity best_specificity best_acc
# 0     rl_model_5000_steps.zip    -0.825241  0.332192     0.980392   0.257732  0.408163     0.402490      117.438356           105.771784          172.568627                                         x
# 1    rl_model_10000_steps.zip    -0.554258  0.400685     0.960784   0.252577  0.400000     0.398340       90.438356            85.987552          111.470588                                         x
# 2    rl_model_15000_steps.zip    -0.022254  0.602740     0.823529   0.308824  0.449198     0.609959       57.482877            58.597510           52.215686
# ...

# %% [markdown]
# ## Model 1

# %%
# !python -W ignore train.py --path '../models/model_comparison/model_1/' --timesteps 50000 --custom_callback --save_every_x_steps 5000
# Out:
# ---------------------------------------------------------------------------------------
# Model Evaluation on TRAINING DATA (last 100 episodes)
# ---------------------------------------------------------------------------------------
# [1.00%/100%] train_steps 500 (eps 348), mean_reward: 0.12 +/- 0.99, acc: 0.56, mean_timesteps: 1.41 +/- 0.75
# [2.00%/100%] train_steps 1000 (eps 701), mean_reward: 0.26 +/- 0.97, acc: 0.63, mean_timesteps: 1.39 +/- 0.71
# [3.00%/100%] train_steps 1500 (eps 1089), mean_reward: 0.26 +/- 0.97, acc: 0.63, mean_timesteps: 1.18 +/- 0.55
# [4.00%/100%] train_steps 2000 (eps 1443), mean_reward: 0.30 +/- 0.95, acc: 0.65, mean_timesteps: 1.32 +/- 0.95
# [5.00%/100%] train_steps 2500 (eps 1654), mean_reward: 0.26 +/- 0.97, acc: 0.63, mean_timesteps: 2.43 +/- 1.84
# [6.00%/100%] train_steps 3000 (eps 1804), mean_reward: 0.14 +/- 0.99, acc: 0.57, mean_timesteps: 3.56 +/- 3.02
# ...

# %%
# !python -W ignore evaluate.py --path '../models/model_comparison/model_1/' --evaluation_summary
# Out:
# Evaluation Summary on Test_Data ( 292 data points)
#                       model  mean_reward       acc  sensitivity  precision        f1  specificity        gm  mean_timesteps  mean_timesteps_good  mean_timesteps_bad best_mean_reward best_f1 best_sensitivity best_specificity best_acc best_gm
# 0   rl_model_5000_steps.zip     0.366390  0.743151     0.392157   0.400000  0.396040     0.875519  0.585953       33.506849            28.854772           55.490196
# 1  rl_model_10000_steps.zip     0.643593  0.835616     0.431373   0.536585  0.478261     0.921162  0.630368       14.308219            12.390041           23.372549
# 2  rl_model_15000_steps.zip     0.649529  0.828767     0.372549   0.513514  0.431818     0.925311  0.587132        5.010274             4.564315            7.117647
# ...

# %% [markdown]
# ## Model 2

# %%
# !python -W ignore train.py --path '../models/model_comparison/model_2/' --timesteps 50000 --custom_callback --save_every_x_steps 5000 --layer_normalization
# Out:
# ---------------------------------------------------------------------------------------
# Model Evaluation on TRAINING DATA (last 100 episodes)
# ---------------------------------------------------------------------------------------
# [1.00%/100%] train_steps 500 (eps 310), mean_reward: 0.14 +/- 0.99, acc: 0.57, mean_timesteps: 1.51 +/- 1.03
# [2.00%/100%] train_steps 1000 (eps 640), mean_reward: 0.04 +/- 1.00, acc: 0.52, mean_timesteps: 1.44 +/- 0.82
# [3.00%/100%] train_steps 1500 (eps 999), mean_reward: 0.42 +/- 0.91, acc: 0.71, mean_timesteps: 1.43 +/- 0.86
# [4.00%/100%] train_steps 2000 (eps 1289), mean_reward: 0.30 +/- 0.95, acc: 0.65, mean_timesteps: 1.80 +/- 1.40
# [5.00%/100%] train_steps 2500 (eps 1534), mean_reward: 0.14 +/- 0.99, acc: 0.57, mean_timesteps: 1.94 +/- 1.36
# [6.00%/100%] train_steps 3000 (eps 1735), mean_reward: 0.28 +/- 0.96, acc: 0.64, mean_timesteps: 2.62 +/- 1.74
# ...

# %%
# !python -W ignore evaluate.py --path '../models/model_comparison/model_2/' --evaluation_summary
# Out:
# Evaluation Summary on Test_Data ( 292 data points)
#                       model  mean_reward       acc  sensitivity  precision        f1  specificity        gm  mean_timesteps  mean_timesteps_good  mean_timesteps_bad best_mean_reward best_f1 best_sensitivity best_specificity best_acc best_gm
# 0   rl_model_5000_steps.zip     0.673547  0.839041     0.117647   0.750000  0.203390     0.991701  0.341571        4.205479             3.804979            6.098039                                                          x
# 1  rl_model_10000_steps.zip     0.629058  0.852740     0.235294   0.750000  0.358209     0.983402  0.481029       30.356164            29.381743           34.960784                                                          x
# 2  rl_model_15000_steps.zip     0.702529  0.856164     0.450980   0.621622  0.522727     0.941909  0.651753        6.650685             5.834025           10.509804
# ...

# %% [markdown]
# ## Model 3

# %%
# !python -W ignore train.py --path '../models/model_comparison/model_3/' --timesteps 50000 --custom_callback --save_every_x_steps 5000 --dueling
# Out:
# ---------------------------------------------------------------------------------------
# Model Evaluation on TRAINING DATA (last 100 episodes)
# ---------------------------------------------------------------------------------------
# [1.00%/100%] train_steps 500 (eps 340), mean_reward: 0.26 +/- 0.97, acc: 0.63, mean_timesteps: 1.47 +/- 0.77
# [2.00%/100%] train_steps 1000 (eps 698), mean_reward: 0.10 +/- 0.99, acc: 0.55, mean_timesteps: 1.35 +/- 0.78
# [3.00%/100%] train_steps 1500 (eps 1070), mean_reward: 0.34 +/- 0.94, acc: 0.67, mean_timesteps: 1.21 +/- 0.60
# [4.00%/100%] train_steps 2000 (eps 1420), mean_reward: 0.18 +/- 0.98, acc: 0.59, mean_timesteps: 1.44 +/- 1.28
# [5.00%/100%] train_steps 2500 (eps 1712), mean_reward: 0.32 +/- 0.95, acc: 0.66, mean_timesteps: 1.81 +/- 1.51
# [6.00%/100%] train_steps 3000 (eps 1935), mean_reward: 0.28 +/- 0.96, acc: 0.64, mean_timesteps: 2.39 +/- 2.85
# ...

# %%
# !python -W ignore evaluate.py --path '../models/model_comparison/model_3/' --evaluation_summary
# Out:
# Evaluation Summary on Test_Data ( 292 data points)
#                       model  mean_reward       acc  sensitivity  precision        f1  specificity        gm  mean_timesteps  mean_timesteps_good  mean_timesteps_bad best_mean_reward best_f1 best_sensitivity best_specificity best_acc best_gm
# 0   rl_model_5000_steps.zip    -0.443150  0.445205     0.509804   0.173333  0.258706     0.485477  0.497492       83.017123            88.224066           58.411765
# 1  rl_model_10000_steps.zip     0.637217  0.821918     0.529412   0.490909  0.509434     0.883817  0.684035        4.582192             3.871369            7.941176
# 2  rl_model_15000_steps.zip     0.701101  0.856164     0.411765   0.636364  0.500000     0.950207  0.625509        6.503425             4.643154           15.294118                                                          x
# ...

# %% [markdown]
# ## Model 4

# %%
# !python -W ignore train.py --path '../models/model_comparison/model_4/' --timesteps 50000 --custom_callback --save_every_x_steps 5000 --double_q
# Out:
# ---------------------------------------------------------------------------------------
# Model Evaluation on TRAINING DATA (last 100 episodes)
# ---------------------------------------------------------------------------------------
# [1.00%/100%] train_steps 500 (eps 348), mean_reward: 0.12 +/- 0.99, acc: 0.56, mean_timesteps: 1.41 +/- 0.75
# [2.00%/100%] train_steps 1000 (eps 701), mean_reward: 0.26 +/- 0.97, acc: 0.63, mean_timesteps: 1.39 +/- 0.71
# [3.00%/100%] train_steps 1500 (eps 1089), mean_reward: 0.26 +/- 0.97, acc: 0.63, mean_timesteps: 1.18 +/- 0.55
# [4.00%/100%] train_steps 2000 (eps 1469), mean_reward: 0.28 +/- 0.96, acc: 0.64, mean_timesteps: 1.23 +/- 0.55
# [5.00%/100%] train_steps 2500 (eps 1730), mean_reward: 0.30 +/- 0.95, acc: 0.65, mean_timesteps: 2.01 +/- 1.37
# [6.00%/100%] train_steps 3000 (eps 1900), mean_reward: 0.10 +/- 1.00, acc: 0.55, mean_timesteps: 3.28 +/- 2.46
# ...

# %%
# !python -W ignore evaluate.py --path '../models/model_comparison/model_4/' --evaluation_summary
# Out:
# Evaluation Summary on Test_Data ( 292 data points)
#                       model  mean_reward       acc  sensitivity  precision        f1  specificity        gm  mean_timesteps  mean_timesteps_good  mean_timesteps_bad best_mean_reward best_f1 best_sensitivity best_specificity best_acc best_gm
# 0   rl_model_5000_steps.zip    -0.321870  0.493151     0.980392   0.297619  0.456621     0.510373  0.707366       75.304795            69.406639          103.176471                                         x
# 1  rl_model_10000_steps.zip     0.684799  0.845890     0.274510   0.636364  0.383562     0.966805  0.515167        5.613014             5.112033            7.980392                                                          x
# 2  rl_model_15000_steps.zip     0.700218  0.852740     0.352941   0.642857  0.455696     0.958506  0.581632        4.133562             4.460581            2.588235                                                          x
# ...

# %% [markdown]
# ## Model 5

# %%
# !python -W ignore train.py --path '../models/model_comparison/model_5/' --timesteps 50000 --custom_callback --save_every_x_steps 5000 --pos_reward_bad_wafer '0.3' --neg_reward_bad_wafer '0.3'
# Out:
# ---------------------------------------------------------------------------------------
# Model Evaluation on TRAINING DATA (last 100 episodes)
# ---------------------------------------------------------------------------------------
# [1.00%/100%] train_steps 500 (eps 348), mean_reward: 0.30 +/- 0.69, acc: 0.56, mean_timesteps: 1.41 +/- 0.75
# [2.00%/100%] train_steps 1000 (eps 701), mean_reward: 0.43 +/- 0.69, acc: 0.63, mean_timesteps: 1.39 +/- 0.71
# [3.00%/100%] train_steps 1500 (eps 1088), mean_reward: 0.42 +/- 0.75, acc: 0.67, mean_timesteps: 1.18 +/- 0.55
# [4.00%/100%] train_steps 2000 (eps 1445), mean_reward: 0.48 +/- 0.69, acc: 0.69, mean_timesteps: 1.30 +/- 0.61
# [5.00%/100%] train_steps 2500 (eps 1667), mean_reward: 0.36 +/- 0.70, acc: 0.61, mean_timesteps: 2.35 +/- 1.75
# [6.00%/100%] train_steps 3000 (eps 1820), mean_reward: 0.31 +/- 0.69, acc: 0.58, mean_timesteps: 3.58 +/- 2.89
# ...

# %%
# !python -W ignore evaluate.py --path '../models/model_comparison/model_5/' --pos_reward_bad_wafer '0.3' --neg_reward_bad_wafer '0.3' --evaluation_summary
# Out:
# Evaluation Summary on Test_Data ( 292 data points)
#                       model  mean_reward       acc  sensitivity  precision        f1  specificity        gm  mean_timesteps  mean_timesteps_good  mean_timesteps_bad best_mean_reward best_f1 best_sensitivity best_specificity best_acc best_gm
# 0   rl_model_5000_steps.zip     0.252187  0.691781     0.196078   0.204082  0.200000     0.838174  0.405398       34.804795            34.024896           38.490196
# 1  rl_model_10000_steps.zip     0.645809  0.835616     0.117647   0.666667  0.200000     0.987552  0.340856       11.123288            10.340249           14.823529                                                          x
# 2  rl_model_15000_steps.zip     0.671259  0.852740     0.372549   0.633333  0.469136     0.954357  0.596276        9.260274             8.983402           10.568627
# ...

# %% [markdown]
# ## Model 6

# %%
# !python -W ignore train.py --path '../models/model_comparison/model_6/' --timesteps 50000 --custom_callback --save_every_x_steps 5000 --discount_wait '0.0001'
# Out:
# ---------------------------------------------------------------------------------------
# Model Evaluation on TRAINING DATA (last 100 episodes)
# ---------------------------------------------------------------------------------------
# [1.00%/100%] train_steps 500 (eps 348), mean_reward: 0.12 +/- 0.99, acc: 0.56, mean_timesteps: 1.41 +/- 0.75
# [2.00%/100%] train_steps 1000 (eps 701), mean_reward: 0.26 +/- 0.97, acc: 0.63, mean_timesteps: 1.39 +/- 0.71
# [3.00%/100%] train_steps 1500 (eps 1089), mean_reward: 0.26 +/- 0.97, acc: 0.63, mean_timesteps: 1.18 +/- 0.55
# [4.00%/100%] train_steps 2000 (eps 1449), mean_reward: 0.28 +/- 0.96, acc: 0.64, mean_timesteps: 1.23 +/- 0.55
# [5.00%/100%] train_steps 2500 (eps 1668), mean_reward: 0.20 +/- 0.98, acc: 0.60, mean_timesteps: 2.39 +/- 1.99
# [6.00%/100%] train_steps 3000 (eps 1823), mean_reward: 0.06 +/- 1.00, acc: 0.53, mean_timesteps: 3.39 +/- 2.76
# ...

# %%
# !python -W ignore evaluate.py --path '../models/model_comparison/model_6/' --discount_wait '0.0001' --evaluation_summary
# Out:
# Evaluation Summary on Test_Data ( 292 data points)
#                       model  mean_reward       acc  sensitivity  precision        f1  specificity        gm  mean_timesteps  mean_timesteps_good  mean_timesteps_bad best_mean_reward best_f1 best_sensitivity best_specificity best_acc best_gm
# 0   rl_model_5000_steps.zip     0.545755  0.773973     0.607843   0.402597  0.484375     0.809129  0.701301       11.743151            11.419087           13.274510
# 1  rl_model_10000_steps.zip    -0.038951  0.493151     0.921569   0.283133  0.433180     0.506224  0.683023       65.770548            59.095436           97.313725                                         x
# 2  rl_model_15000_steps.zip     0.653850  0.828767     0.490196   0.595238  0.537634     0.929461  0.674995       13.003425             9.012448           31.862745                                                          x
# ...

# %% [markdown]
# ## Model 7

# %%
# !python -W ignore train.py --path '../models/model_comparison/model_7/' --timesteps 50000 --custom_callback --save_every_x_steps 5000 --buffer_size_replay 20000
# Out:
# ---------------------------------------------------------------------------------------
# Model Evaluation on TRAINING DATA (last 100 episodes)
# ---------------------------------------------------------------------------------------
# [1.00%/100%] train_steps 500 (eps 348), mean_reward: 0.12 +/- 0.99, acc: 0.56, mean_timesteps: 1.41 +/- 0.75
# [2.00%/100%] train_steps 1000 (eps 701), mean_reward: 0.26 +/- 0.97, acc: 0.63, mean_timesteps: 1.39 +/- 0.71
# [3.00%/100%] train_steps 1500 (eps 1089), mean_reward: 0.26 +/- 0.97, acc: 0.63, mean_timesteps: 1.18 +/- 0.55
# [4.00%/100%] train_steps 2000 (eps 1443), mean_reward: 0.30 +/- 0.95, acc: 0.65, mean_timesteps: 1.32 +/- 0.95
# [5.00%/100%] train_steps 2500 (eps 1654), mean_reward: 0.26 +/- 0.97, acc: 0.63, mean_timesteps: 2.43 +/- 1.84
# [6.00%/100%] train_steps 3000 (eps 1804), mean_reward: 0.14 +/- 0.99, acc: 0.57, mean_timesteps: 3.56 +/- 3.02
# ...

# %%
# !python -W ignore evaluate.py --path '../models/model_comparison/model_7/' --evaluation_summary
# Out:
# Evaluation Summary on Test_Data ( 292 data points)
#                       model  mean_reward       acc  sensitivity  precision        f1  specificity        gm  mean_timesteps  mean_timesteps_good  mean_timesteps_bad best_mean_reward best_f1 best_sensitivity best_specificity best_acc best_gm
# 0   rl_model_5000_steps.zip     0.366390  0.743151     0.392157   0.400000  0.396040     0.875519  0.585953       33.506849            28.854772           55.490196
# 1  rl_model_10000_steps.zip     0.643593  0.835616     0.431373   0.536585  0.478261     0.921162  0.630368       14.308219            12.390041           23.372549
# 2  rl_model_15000_steps.zip     0.649529  0.828767     0.372549   0.513514  0.431818     0.925311  0.587132        5.010274             4.564315            7.117647
# 3  rl_model_20000_steps.zip     0.690445  0.849315     0.411765   0.600000  0.488372     0.941909  0.622772        5.825342             5.029046            9.588235
# ...

# %% [markdown]
# ## Model 8

# %%
# !python -W ignore train.py --path '../models/model_comparison/model_8/' --timesteps 50000 --custom_callback --save_every_x_steps 5000  --pos_reward_good_wafer '0.3' --neg_reward_good_wafer '0.3'
# Out:
# ---------------------------------------------------------------------------------------
# Model Evaluation on TRAINING DATA (last 100 episodes)
# ---------------------------------------------------------------------------------------
# [1.00%/100%] train_steps 500 (eps 348), mean_reward: -0.15 +/- 0.71, acc: 0.56, mean_timesteps: 1.41 +/- 0.75
# [2.00%/100%] train_steps 1000 (eps 701), mean_reward: -0.10 +/- 0.65, acc: 0.63, mean_timesteps: 1.39 +/- 0.71
# [3.00%/100%] train_steps 1500 (eps 1072), mean_reward: -0.09 +/- 0.60, acc: 0.59, mean_timesteps: 1.21 +/- 0.57
# [4.00%/100%] train_steps 2000 (eps 1383), mean_reward: -0.14 +/- 0.63, acc: 0.60, mean_timesteps: 1.47 +/- 0.89
# [5.00%/100%] train_steps 2500 (eps 1606), mean_reward: -0.13 +/- 0.67, acc: 0.56, mean_timesteps: 2.27 +/- 1.63
# [6.00%/100%] train_steps 3000 (eps 1787), mean_reward: -0.00 +/- 0.69, acc: 0.65, mean_timesteps: 2.94 +/- 2.42
# ...

# %%
# !python -W ignore evaluate.py --path '../models/model_comparison/model_8/' --pos_reward_good_wafer '0.3' --neg_reward_good_wafer '0.3' --evaluation_summary
# Out:
# Evaluation Summary on Test_Data ( 292 data points)
#                       model  mean_reward       acc  sensitivity  precision        f1  specificity        gm  mean_timesteps  mean_timesteps_good  mean_timesteps_bad best_mean_reward best_f1 best_sensitivity best_specificity best_acc best_gm
# 0   rl_model_5000_steps.zip     0.072482  0.763699     0.784314   0.408163  0.536913     0.759336  0.771724       19.688356            18.763485           24.058824                                         x                                 x
# 1  rl_model_10000_steps.zip     0.226960  0.859589     0.372549   0.678571  0.481013     0.962656  0.598863        7.575342             7.352697            8.627451                                                          x
# 2  rl_model_15000_steps.zip     0.176027  0.815068     0.705882   0.480000  0.571429     0.838174  0.769189        5.116438             5.091286            5.235294                                         x
# ...

# %% [markdown]
# ## Model 9

# %%
# !python -W ignore train.py --path '../models/model_comparison/model_9/' --timesteps 50000 --custom_callback --save_every_x_steps 5000 --pos_reward_good_wafer '0.3' --neg_reward_bad_wafer '0.3'
# Out:
# ---------------------------------------------------------------------------------------
# Model Evaluation on TRAINING DATA (last 100 episodes)
# ---------------------------------------------------------------------------------------
# [1.00%/100%] train_steps 500 (eps 348), mean_reward: 0.06 +/- 0.50, acc: 0.56, mean_timesteps: 1.41 +/- 0.75
# [2.00%/100%] train_steps 1000 (eps 701), mean_reward: 0.08 +/- 0.44, acc: 0.63, mean_timesteps: 1.39 +/- 0.71
# [3.00%/100%] train_steps 1500 (eps 1048), mean_reward: 0.15 +/- 0.48, acc: 0.65, mean_timesteps: 1.22 +/- 0.66
# [4.00%/100%] train_steps 2000 (eps 1368), mean_reward: 0.08 +/- 0.43, acc: 0.62, mean_timesteps: 1.54 +/- 0.81
# [5.00%/100%] train_steps 2500 (eps 1619), mean_reward: 0.07 +/- 0.53, acc: 0.55, mean_timesteps: 2.02 +/- 1.69
# [6.00%/100%] train_steps 3000 (eps 1794), mean_reward: 0.12 +/- 0.53, acc: 0.58, mean_timesteps: 3.01 +/- 2.31
# ...

# %%
# !python -W ignore evaluate.py --path '../models/model_comparison/model_9/' --pos_reward_good_wafer '0.3' --neg_reward_bad_wafer '0.3'
# Out:
# Evaluation Summary on  Test_Data  ( 292  data points )
#                       model  mean_reward       acc  sensitivity  precision        f1  specificity  mean_timesteps  mean_timesteps_good  mean_timesteps_bad best_mean_reward best_f1 best_sensitivity best_specificity best_acc
# 0   rl_model_5000_steps.zip     0.188755  0.702055     0.980392   0.367647  0.534759     0.643154       10.167808            11.580913            3.490196                                         x
# 1  rl_model_10000_steps.zip     0.261952  0.791096     0.882353   0.450000  0.596026     0.771784        4.965753             5.580913            2.058824
# 2  rl_model_15000_steps.zip     0.278071  0.794521     0.921569   0.456311  0.610390     0.767635        2.421233             2.506224            2.019608
# 3  rl_model_20000_steps.zip     0.274095  0.832192     0.823529   0.512195  0.631579     0.834025        3.797945             3.867220            3.470588
# ...

# %% [markdown]
# ## Model 10

# %%
# !python -W ignore train.py --path '../models/model_comparison/model_10/' --timesteps 50000 --custom_callback --save_every_x_steps 5000 --prioritized_replay
# Out:
# ---------------------------------------------------------------------------------------
# Model Evaluation on TRAINING DATA (last 100 episodes)
# ---------------------------------------------------------------------------------------
# [1.00%/100%] train_steps 500 (eps 348), mean_reward: 0.12 +/- 0.99, acc: 0.56, mean_timesteps: 1.41 +/- 0.75
# [2.00%/100%] train_steps 1000 (eps 701), mean_reward: 0.26 +/- 0.97, acc: 0.63, mean_timesteps: 1.39 +/- 0.71
# [3.00%/100%] train_steps 1500 (eps 1089), mean_reward: 0.26 +/- 0.97, acc: 0.63, mean_timesteps: 1.18 +/- 0.55
# [4.00%/100%] train_steps 2000 (eps 1458), mean_reward: 0.28 +/- 0.96, acc: 0.64, mean_timesteps: 1.23 +/- 0.53
# [5.00%/100%] train_steps 2500 (eps 1749), mean_reward: 0.18 +/- 0.98, acc: 0.59, mean_timesteps: 1.89 +/- 1.79
# [6.00%/100%] train_steps 3000 (eps 1923), mean_reward: 0.18 +/- 0.98, acc: 0.59, mean_timesteps: 3.39 +/- 2.86
# ...

# %%
# !python -W ignore evaluate.py --path '../models/model_comparison/model_10/'
# Out:
# Evaluation Summary on  Test_Data  ( 292  data points )
#                       model  mean_reward       acc  sensitivity  precision        f1  specificity  mean_timesteps  mean_timesteps_good  mean_timesteps_bad best_mean_reward best_f1 best_sensitivity best_specificity best_acc
# 0   rl_model_5000_steps.zip    -0.915280  0.280822     0.882353   0.202703  0.329670     0.265560      116.602740           120.468880           98.333333                                         x
# 1  rl_model_10000_steps.zip     0.689896  0.859589     0.313725   0.727273  0.438356     0.975104       13.448630            12.970954           15.705882                                                          x
# 2  rl_model_15000_steps.zip     0.644017  0.832192     0.490196   0.520833  0.505051     0.904564       10.366438            10.012448           12.039216
# ...

# %% [markdown]
# ## Model 11

# %%
# !python -W ignore train.py --path '../models/model_comparison/model_11/' --timesteps 50000 --custom_callback --save_every_x_steps 5000 --prioritized_replay --buffer_size_replay 2500
# Out:
# ---------------------------------------------------------------------------------------
# Model Evaluation on TRAINING DATA (last 100 episodes)
# ---------------------------------------------------------------------------------------
# [1.00%/100%] train_steps 500 (eps 348), mean_reward: 0.12 +/- 0.99, acc: 0.56, mean_timesteps: 1.41 +/- 0.75
# [2.00%/100%] train_steps 1000 (eps 701), mean_reward: 0.26 +/- 0.97, acc: 0.63, mean_timesteps: 1.39 +/- 0.71
# [3.00%/100%] train_steps 1500 (eps 1089), mean_reward: 0.26 +/- 0.97, acc: 0.63, mean_timesteps: 1.18 +/- 0.55
# [4.00%/100%] train_steps 2000 (eps 1458), mean_reward: 0.28 +/- 0.96, acc: 0.64, mean_timesteps: 1.23 +/- 0.53
# [5.00%/100%] train_steps 2500 (eps 1749), mean_reward: 0.18 +/- 0.98, acc: 0.59, mean_timesteps: 1.89 +/- 1.79
# [6.00%/100%] train_steps 3000 (eps 1943), mean_reward: 0.40 +/- 0.92, acc: 0.70, mean_timesteps: 2.88 +/- 2.76
# ...

# %%
# !python -W ignore evaluate.py --path '../models/model_comparison/model_11/'
# Out:
# Evaluation Summary on  Test_Data  ( 292  data points )
#                       model  mean_reward       acc  sensitivity  precision        f1  specificity  mean_timesteps  mean_timesteps_good  mean_timesteps_bad best_mean_reward best_f1 best_sensitivity best_specificity best_acc
# 0   rl_model_5000_steps.zip    -0.313914  0.510274     0.725490   0.280303  0.404372     0.605809       83.222603            75.539419          119.529412                                         x
# 1  rl_model_10000_steps.zip     0.609141  0.828767     0.274510   0.518519  0.358974     0.946058       21.544521            20.265560           27.588235
# 2  rl_model_15000_steps.zip     0.562974  0.797945     0.450980   0.425926  0.438095     0.871369       15.750000            14.132780           23.392157
# 3  rl_model_20000_steps.zip     0.671939  0.845890     0.450980   0.575000  0.505495     0.929461       11.181507            10.145228           16.078431
# ...

# %% [markdown]
# ## Model 12

# %%
# !python -W ignore train.py --path '../models/model_comparison/model_12/' --timesteps 50000 --custom_callback --save_every_x_steps 5000 --prioritized_replay --buffer_size_replay 5000
# Out:
# ---------------------------------------------------------------------------------------
# Model Evaluation on TRAINING DATA (last 100 episodes)
# ---------------------------------------------------------------------------------------
# [1.00%/100%] train_steps 500 (eps 348), mean_reward: 0.12 +/- 0.99, acc: 0.56, mean_timesteps: 1.41 +/- 0.75
# [2.00%/100%] train_steps 1000 (eps 701), mean_reward: 0.26 +/- 0.97, acc: 0.63, mean_timesteps: 1.39 +/- 0.71
# [3.00%/100%] train_steps 1500 (eps 1089), mean_reward: 0.26 +/- 0.97, acc: 0.63, mean_timesteps: 1.18 +/- 0.55
# [4.00%/100%] train_steps 2000 (eps 1458), mean_reward: 0.28 +/- 0.96, acc: 0.64, mean_timesteps: 1.23 +/- 0.53
# [5.00%/100%] train_steps 2500 (eps 1749), mean_reward: 0.18 +/- 0.98, acc: 0.59, mean_timesteps: 1.89 +/- 1.79
# [6.00%/100%] train_steps 3000 (eps 1923), mean_reward: 0.18 +/- 0.98, acc: 0.59, mean_timesteps: 3.39 +/- 2.86
# ...

# %%
# !python -W ignore evaluate.py --path '../models/model_comparison/model_12/'
# Out:
# Evaluation Summary on  Test_Data  ( 292  data points )
#                       model  mean_reward       acc  sensitivity  precision        f1  specificity  mean_timesteps  mean_timesteps_good  mean_timesteps_bad best_mean_reward best_f1 best_sensitivity best_specificity best_acc
# 0   rl_model_5000_steps.zip    -0.915280  0.280822     0.882353   0.202703  0.329670     0.265560      116.602740           120.468880           98.333333                                         x
# 1  rl_model_10000_steps.zip     0.612875  0.825342     0.254902   0.500000  0.337662     0.946058       16.085616            16.165975           15.705882
# 2  rl_model_15000_steps.zip     0.700424  0.866438     0.372549   0.730769  0.493506     0.970954       15.517123            12.647303           29.078431                                                          x
# ...

# %% [markdown]
# ## Model 13

# %%
# !python -W ignore train.py --path '../models/model_comparison/model_13/' --timesteps 50000 --custom_callback --save_every_x_steps 5000 --prioritized_replay --buffer_size_replay 10000
# Out:
# ---------------------------------------------------------------------------------------
# Model Evaluation on TRAINING DATA (last 100 episodes)
# ---------------------------------------------------------------------------------------
# [1.00%/100%] train_steps 500 (eps 348), mean_reward: 0.12 +/- 0.99, acc: 0.56, mean_timesteps: 1.41 +/- 0.75
# [2.00%/100%] train_steps 1000 (eps 701), mean_reward: 0.26 +/- 0.97, acc: 0.63, mean_timesteps: 1.39 +/- 0.71
# [3.00%/100%] train_steps 1500 (eps 1089), mean_reward: 0.26 +/- 0.97, acc: 0.63, mean_timesteps: 1.18 +/- 0.55
# [4.00%/100%] train_steps 2000 (eps 1458), mean_reward: 0.28 +/- 0.96, acc: 0.64, mean_timesteps: 1.23 +/- 0.53
# [5.00%/100%] train_steps 2500 (eps 1749), mean_reward: 0.18 +/- 0.98, acc: 0.59, mean_timesteps: 1.89 +/- 1.79
# [6.00%/100%] train_steps 3000 (eps 1923), mean_reward: 0.18 +/- 0.98, acc: 0.59, mean_timesteps: 3.39 +/- 2.86
# ...

# %%
# !python -W ignore evaluate.py --path '../models/model_comparison/model_13/'
# Out:
# Evaluation Summary on  Test_Data  ( 292  data points )
#                       model  mean_reward       acc  sensitivity  precision        f1  specificity  mean_timesteps  mean_timesteps_good  mean_timesteps_bad best_mean_reward best_f1 best_sensitivity best_specificity best_acc
# 0   rl_model_5000_steps.zip    -0.915280  0.280822     0.882353   0.202703  0.329670     0.265560      116.602740           120.468880           98.333333                                         x
# 1  rl_model_10000_steps.zip     0.689896  0.859589     0.313725   0.727273  0.438356     0.975104       13.448630            12.970954           15.705882                                                          x        x
# 2  rl_model_15000_steps.zip     0.650876  0.835616     0.450980   0.534884  0.489362     0.917012       10.438356             9.875519           13.098039
# ...

# %% [markdown]
# ## Model 14

# %%
# !python -W ignore train.py --path '../models/model_comparison/model_14/' --timesteps 50000 --custom_callback --save_every_x_steps 5000 --prioritized_replay --buffer_size_replay 20000
# Out:
# ---------------------------------------------------------------------------------------
# Model Evaluation on TRAINING DATA (last 100 episodes)
# ---------------------------------------------------------------------------------------
# [1.00%/100%] train_steps 500 (eps 348), mean_reward: 0.12 +/- 0.99, acc: 0.56, mean_timesteps: 1.41 +/- 0.75
# [2.00%/100%] train_steps 1000 (eps 701), mean_reward: 0.26 +/- 0.97, acc: 0.63, mean_timesteps: 1.39 +/- 0.71
# [3.00%/100%] train_steps 1500 (eps 1089), mean_reward: 0.26 +/- 0.97, acc: 0.63, mean_timesteps: 1.18 +/- 0.55
# [4.00%/100%] train_steps 2000 (eps 1458), mean_reward: 0.28 +/- 0.96, acc: 0.64, mean_timesteps: 1.23 +/- 0.53
# [5.00%/100%] train_steps 2500 (eps 1749), mean_reward: 0.18 +/- 0.98, acc: 0.59, mean_timesteps: 1.89 +/- 1.79
# [6.00%/100%] train_steps 3000 (eps 1923), mean_reward: 0.18 +/- 0.98, acc: 0.59, mean_timesteps: 3.39 +/- 2.86
# ...

# %%
# !python -W ignore evaluate.py --path '../models/model_comparison/model_14/'
# Out:
# Evaluation Summary on  Test_Data  ( 292  data points )
#                       model  mean_reward       acc  sensitivity  precision        f1  specificity  mean_timesteps  mean_timesteps_good  mean_timesteps_bad best_mean_reward best_f1 best_sensitivity best_specificity best_acc
# 0   rl_model_5000_steps.zip    -0.915280  0.280822     0.882353   0.202703  0.329670     0.265560      116.602740           120.468880           98.333333                                         x
# 1  rl_model_10000_steps.zip     0.689896  0.859589     0.313725   0.727273  0.438356     0.975104       13.448630            12.970954           15.705882                                                          x
# 2  rl_model_15000_steps.zip     0.644017  0.832192     0.490196   0.520833  0.505051     0.904564       10.366438            10.012448           12.039216
# ...

# %% [markdown]
# ## Grafische Auswertung

# %%
# %run plot.py --path '../models/model_comparison/model_1/','../models/model_comparison/model_2/','../models/model_comparison/model_3/','../models/model_comparison/model_4/','../models/model_comparison/model_5/','../models/model_comparison/model_6/','../models/model_comparison/model_7/','../models/model_comparison/model_8/','../models/model_comparison/model_9/','../models/model_comparison/model_10/','../models/model_comparison/model_11/','../models/model_comparison/model_12/' --x_axis 'timesteps' --smoothing 1000

# %%
# %run plot.py --path '../models/model_comparison/model_1/','../models/model_comparison/model_2/','../models/model_comparison/model_3/','../models/model_comparison/model_4/','../models/model_comparison/model_8/','../models/model_comparison/model_9/','../models/model_comparison/model_12/','../models/model_comparison/model_14/' --x_axis 'timesteps' --smoothing 1000

# %% [markdown]
# # Experiment: Gute Hyperparameter werden kombiniert

# %% [markdown]
# ## Model 15

# %%
# !python -W ignore train.py --path '../models/model_comparison/model_15/' --timesteps 50000 --custom_callback --save_every_x_steps 5000

# %%
# !python -W ignore evaluate.py --path '../models/model_comparison/model_15/'

# %% [markdown]
# ## Model 16

# %%
# !python -W ignore train.py --path '../models/model_comparison/model_16/' --timesteps 50000 --custom_callback --save_every_x_steps 5000

# %%
# !python -W ignore evaluate.py --path '../models/model_comparison/model_16/'

# %% [markdown]
# ## Model 17

# %%
# !python -W ignore train.py --path '../models/model_comparison/model_17/' --timesteps 50000 --custom_callback --save_every_x_steps 5000

# %%
# !python -W ignore evaluate.py --path '../models/model_comparison/model_17/'

# %% [markdown]
# ## Model 18

# %%
# !python -W ignore train.py --path '../models/model_comparison/model_18/' --timesteps 50000 --custom_callback --save_every_x_steps 5000

# %%
# !python -W ignore evaluate.py --path '../models/model_comparison/model_18/'

# %% [markdown]
# ## Model 19

# %%
# !python -W ignore train.py --path '../models/model_comparison/model_19/' --timesteps 50000 --custom_callback --save_every_x_steps 5000

# %%
# !python -W ignore evaluate.py --path '../models/model_comparison/model_19/'

# %% [markdown]
# ## Model 20

# %%
# !python -W ignore train.py --path '../models/model_comparison/model_20/' --timesteps 50000 --custom_callback --save_every_x_steps 5000

# %%
# !python -W ignore evaluate.py --path '../models/model_comparison/model_20/'
