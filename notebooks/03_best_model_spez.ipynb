# %% [markdown]
# # Installation Requirements

# %%
# !pip uninstall --quiet tensorflow --yes
# !pip uninstall --quiet kapre --yes
# !pip install --quiet tensorflow==1.14.0
# !pip install --quiet stable_baselines
# !pip uninstall --quiet optuna --yes
# !pip install --quiet optuna==2.10.0
# !pip uninstall --quiet tensorboard-plugin-wit --yes
# !pip install --quiet "gym==0.19.0"
# Out:
#      |████████████████████████████████| 109.3 MB 51 kB/s
#      |████████████████████████████████| 488 kB 48.4 MB/s
#      |████████████████████████████████| 50 kB 6.3 MB/s
#      |████████████████████████████████| 3.1 MB 38.3 MB/s
#      |████████████████████████████████| 240 kB 5.4 MB/s
#      |████████████████████████████████| 18.3 MB 90 kB/s
#      |████████████████████████████████| 1.6 MB 55.7 MB/s
# WARNING: Skipping optuna as it is not installed.
#      |████████████████████████████████| 308 kB 5.3 MB/s
#      |████████████████████████████████| 81 kB 6.0 MB/s
#      |████████████████████████████████| 209 kB 55.2 MB/s
#      |████████████████████████████████| 78 kB 7.2 MB/s
#      |████████████████████████████████| 112 kB 60.3 MB/s
#      |████████████████████████████████| 49 kB 6.2 MB/s
#      |████████████████████████████████| 147 kB 60.5 MB/s
# ...
#      |████████████████████████████████| 1.6 MB 5.2 MB/s
# ...

# %%
# Set working directory
# %cd /content/drive/MyDrive/ColabNotebooks/Masterarbeit/RLModel/src

# run config.py to load all required settings  
# %run config.py
# Out:
# /content/drive/MyDrive/ColabNotebooks/Masterarbeit/RLModel/src
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %% [markdown]
# # Analyze Hypertuning

# %%
import optuna
study_name = 'hyperstudy_spez'
storage_name = "sqlite:///{}.db".format(study_name)

study = optuna.load_study(study_name=study_name, storage=storage_name)
study.trials_dataframe(attrs=("number", "value", "params", "state"))
# Out:
#     number     value  params_batch_size  params_buffer_size  params_double_q  \
# 0        0  0.980357                 32               30000             True
# 1        1  0.930357                128               50000             True
# 2        2  0.969643                128               20000            False
# 3        3  0.950000                128                5000             True
# 4        4  0.666071                 32               40000            False
# 5        5  0.998214                 64                5000            False
# 6        6  0.975000                128                5000            False
# 7        7  0.942857                 64               40000            False
# 8        8  0.964286                 32                5000            False
# 9        9  0.942857                128               10000            False
# 10      10  0.953571                 64               10000             True
# ...

# %%
from optuna.visualization import plot_param_importances
plot_param_importances(study)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Conclusion
# trial 11 reaches the best spez score
# - 1.Fold: 45.000 training steps
# - 2.Fold: 5.000 training steps
# - 3.Fold: 5.000 training steps
# - 4.Fold: 5.000 training steps
#
# --> Training on all training data with a training steps length of mean(45,5,5,5) = 15.000

# %% [markdown]
# # Train best model

# %%
# !python -W ignore train.py --path '../models/best_models/best_model_spez/' --study_name 'hyperstudy_spez' --timesteps 15000 --custom_callback --train_best_hypermodel
# Out:
# ---------------------------------------------------------------------------------------
# Model Evaluation on TRAINING DATA (last 100 episodes)
# ---------------------------------------------------------------------------------------
# [3.33%/100%] train_steps 500 (eps 381), mean_reward: 0.18 +/- 0.59, acc: 0.42, mean_timesteps: 1.28 +/- 1.72
# [6.67%/100%] train_steps 1000 (eps 727), mean_reward: 0.17 +/- 0.59, acc: 0.41, mean_timesteps: 1.36 +/- 1.49
# [10.00%/100%] train_steps 1500 (eps 1029), mean_reward: 0.65 +/- 0.56, acc: 0.75, mean_timesteps: 1.37 +/- 3.29
# [13.33%/100%] train_steps 2000 (eps 1191), mean_reward: 0.73 +/- 0.53, acc: 0.79, mean_timesteps: 4.21 +/- 10.53
# [16.67%/100%] train_steps 2500 (eps 1281), mean_reward: 0.77 +/- 0.50, acc: 0.84, mean_timesteps: 6.02 +/- 20.23
# [20.00%/100%] train_steps 3000 (eps 1352), mean_reward: 0.78 +/- 0.50, acc: 0.84, mean_timesteps: 5.93 +/- 20.02
# ...

# %%
# !python -W ignore evaluate.py --path '../models/best_models/best_model_spez/' --study_name 'hyperstudy_spez' --train_best_hypermodel --evaluation_summary
# Out:
# Evaluation Summary on Test_Data ( 292 data points)
#                 model  mean_reward       acc  sensitivity  precision        f1  specificity        gm  mean_timesteps  mean_timesteps_good  mean_timesteps_bad best_mean_reward best_f1 best_sensitivity best_specificity best_acc best_gm
# 0  rl_model_final.zip     0.763333  0.825342     0.058824       0.75  0.109091     0.995851  0.242032       10.643836             9.420139                21.5                x       x                x                x        x       x
#
# Evaluation Summary on Train_Data ( 679 data points)
#                 model  mean_reward       acc  sensitivity  precision    f1  specificity        gm  mean_timesteps  mean_timesteps_good  mean_timesteps_bad best_mean_reward best_f1 best_sensitivity best_specificity best_acc best_gm
# ...
