# %% [markdown]
# # Installation Requirements

# %%
# !pip uninstall --quiet tensorflow --yes
# !pip uninstall --quiet kapre --yes
# !pip install --quiet tensorflow==1.14.0
# !pip install --quiet stable_baselines
# !pip uninstall --quiet optuna --yes
# !pip install --quiet optuna==2.10.0
# !pip uninstall --quiet tensorboard-plugin-wit --yes
# !pip install --quiet "gym==0.19.0"
# Out:
#      |████████████████████████████████| 109.3 MB 45 kB/s
#      |████████████████████████████████| 50 kB 5.7 MB/s
#      |████████████████████████████████| 3.1 MB 53.1 MB/s
#      |████████████████████████████████| 488 kB 57.6 MB/s
#      |████████████████████████████████| 240 kB 30.1 MB/s
#      |████████████████████████████████| 18.3 MB 121 kB/s
#      |████████████████████████████████| 1.6 MB 53.5 MB/s
# WARNING: Skipping optuna as it is not installed.
#      |████████████████████████████████| 308 kB 11.6 MB/s
#      |████████████████████████████████| 81 kB 6.7 MB/s
#      |████████████████████████████████| 209 kB 62.9 MB/s
#      |████████████████████████████████| 78 kB 5.5 MB/s
#      |████████████████████████████████| 147 kB 66.7 MB/s
#      |████████████████████████████████| 49 kB 5.4 MB/s
#      |████████████████████████████████| 112 kB 51.2 MB/s
#   Building wheel for pyperclip (setup.py) ... done
#      |████████████████████████████████| 1.6 MB 27.5 MB/s
#   Building wheel for gym (setup.py) ... done

# %%
# Set working directory
# %cd /content/drive/MyDrive/ColabNotebooks/Masterarbeit/RLModel/src

# run config.py to load all required settings  
# %run config.py
# Out:
# /content/drive/MyDrive/ColabNotebooks/Masterarbeit/RLModel/src
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# # Analyze Hypertuning

# %%
import optuna
study_name = 'hyperstudy_gm'
storage_name = "sqlite:///{}.db".format(study_name)

study = optuna.load_study(study_name=study_name, storage=storage_name)
study.trials_dataframe(attrs=("number", "value", "params", "state"))
# Out:
#     number     value  params_batch_size  params_buffer_size  params_double_q  \
# 0        0  0.650691                 32               30000             True
# 1        1  0.773514                128               50000             True
# 2        2  0.780638                128               20000            False
# 3        3  0.788904                128                5000             True
# 4        4  0.640162                 32               40000            False
# 5        5  0.608120                 64                5000            False
# 6        6  0.738417                128                5000            False
# 7        7  0.768516                 64               40000            False
# 8        8  0.705092                 32                5000            False
# 9        9  0.779579                128               10000            False
# 10      10  0.768265                128               10000             True
# 11      11       NaN                128               20000             True
# 12      12  0.746707                128               20000             True
# 13      13  0.740843                128               20000             True
# 14      14  0.784061                128               20000             True
# 15      15  0.786791                128               50000             True
# 16      16  0.804707                 64               50000             True
# 17      17  0.766864                 64               50000             True
# 18      18  0.795662                 64               30000             True
# 19      19  0.815482                 64               30000             True
# 20      20  0.811806                 64               30000             True
# 21      21  0.787170                 64               30000             True
# 22      22  0.811806                 64               30000             True
# 23      23  0.811806                 64               30000             True
# 24      24  0.811806                 64               30000             True
# 25      25  0.811806                 64               30000             True
# 26      26  0.799613                 64               30000             True
# 27      27  0.811806                 64               30000             True
# 28      28  0.817753                 64               30000             True
# 29      29  0.783134                 64               30000             True
# 30      30       NaN                 32               30000             True
# 31      31  0.738425                 32               30000             True
# 32      32  0.643317                 32               30000             True
# 33      33  0.811806                 64               30000             True
# 34      34  0.811806                 64               30000             True
# 35      35  0.854637                 64               30000             True
# 36      36  0.836149                 64               10000             True
# 37      37  0.790592                 64               10000             True
# 38      38  0.689599                 64               10000             True
# 39      39  0.780004                 64               40000             True
# 40      40  0.721283                 32               10000            False
# 41      41  0.812702                 64               10000            False
# 42      42  0.615850                 64               40000             True
#
#     params_dueling  params_exploration_final_eps  params_exploration_fraction  \
# 0            False                           0.1                       0.0100
# 1            False                           0.3                       0.0001
# 2            False                           0.1                       0.0010
# 3             True                           0.1                       0.0001
# 4            False                           0.2                       0.0010
# 5            False                           0.1                       0.0010
# 6            False                           0.1                       0.0100
# 7             True                           0.2                       0.0001
# 8            False                           0.3                       0.0001
# 9            False                           0.3                       0.0010
# 10            True                           0.1                       0.0001
# 11            True                           0.1                       0.0010
# 12            True                           0.1                       0.0010
# 13            True                           0.1                       0.0001
# 14            True                           0.1                       0.0010
# 15            True                           0.1                       0.0100
# 16            True                           0.2                       0.0100
# 17            True                           0.2                       0.0100
# 18            True                           0.2                       0.0100
# 19            True                           0.2                       0.0100
# 20            True                           0.2                       0.0100
# 21            True                           0.2                       0.0100
# 22            True                           0.2                       0.0100
# 23            True                           0.2                       0.0100
# 24            True                           0.2                       0.0100
# 25            True                           0.2                       0.0100
# 26            True                           0.2                       0.0100
# 27            True                           0.2                       0.0100
# 28            True                           0.2                       0.0100
# 29            True                           0.2                       0.0100
# 30            True                           0.3                       0.0100
# 31            True                           0.3                       0.0100
# 32            True                           0.2                       0.0100
# 33            True                           0.2                       0.0100
# 34            True                           0.2                       0.0100
# 35            True                           0.2                       0.0100
# 36            True                           0.2                       0.0100
# 37            True                           0.3                       0.0100
# 38           False                           0.2                       0.0100
# 39            True                           0.2                       0.0100
# 40           False                           0.2                       0.0100
# 41            True                           0.2                       0.0001
# 42           False                           0.3                       0.0010
#
#     params_gamma  params_layer_1  ...  params_negative_reward_good_wafer  \
# 0          0.900              32  ...                                1.0
# 1          0.900              32  ...                                0.8
# 2          0.900              64  ...                                1.0
# 3          0.900              32  ...                                0.8
# 4          0.999             128  ...                                0.8
# 5          0.950              64  ...                                0.5
# 6          0.999             128  ...                                0.8
# 7          0.900              64  ...                                0.8
# 8          0.999              64  ...                                1.0
# 9          0.950             128  ...                                0.8
# 10         0.990              32  ...                                0.3
# 11         0.995              64  ...                                1.0
# 12         0.995              64  ...                                1.0
# 13         0.900              32  ...                                0.3
# 14         0.900              32  ...                                0.5
# 15         0.990              32  ...                                0.5
# 16         0.990              32  ...                                0.5
# 17         0.990              32  ...                                0.5
# 18         0.995              32  ...                                0.5
# 19         0.995              32  ...                                0.5
# 20         0.995              32  ...                                0.5
# 21         0.995             128  ...                                0.5
# 22         0.995              32  ...                                0.5
# 23         0.995              32  ...                                0.5
# 24         0.995              32  ...                                0.5
# 25         0.995              32  ...                                0.5
# 26         0.995              32  ...                                0.3
# 27         0.995              32  ...                                0.5
# 28         0.995              32  ...                                0.5
# 29         0.995              32  ...                                0.5
# 30         0.950             128  ...                                0.5
# 31         0.950             128  ...                                0.5
# 32         0.995              32  ...                                0.3
# 33         0.995              32  ...                                0.5
# 34         0.995              32  ...                                0.5
# 35         0.995              32  ...                                0.5
# 36         0.995              32  ...                                1.0
# 37         0.995              32  ...                                1.0
# 38         0.995              32  ...                                1.0
# 39         0.950              64  ...                                1.0
# 40         0.995              32  ...                                1.0
# 41         0.999             128  ...                                1.0
# 42         0.999              64  ...                                0.8
#
#     params_param_lambda  params_param_noise  params_positive_reward_bad_wafer  \
# 0                0.0001               False                               0.3
# 1                0.0010                True                               0.8
# 2                0.0010               False                               0.8
# 3                0.0100               False                               0.5
# 4                0.0001               False                               0.5
# 5                0.0100                True                               0.3
# 6                0.0010               False                               0.3
# 7                0.0010                True                               0.5
# 8                0.0001                True                               0.5
# 9                0.0100               False                               0.3
# 10               0.0100               False                               1.0
# 11               0.0010               False                               0.8
# 12               0.0010               False                               0.8
# 13               0.0100               False                               0.8
# 14               0.0010               False                               1.0
# 15               0.0100               False                               1.0
# 16               0.0100               False                               1.0
# 17               0.0100               False                               0.5
# 18               0.0100               False                               1.0
# 19               0.0100                True                               1.0
# 20               0.0100                True                               1.0
# 21               0.0100                True                               1.0
# 22               0.0100                True                               1.0
# 23               0.0100                True                               1.0
# 24               0.0100                True                               1.0
# 25               0.0100                True                               1.0
# 26               0.0001                True                               1.0
# 27               0.0100                True                               1.0
# 28               0.0100                True                               1.0
# 29               0.0100                True                               1.0
# 30               0.0001                True                               1.0
# 31               0.0001                True                               1.0
# 32               0.0100                True                               0.3
# 33               0.0100                True                               1.0
# 34               0.0100                True                               1.0
# 35               0.0100                True                               1.0
# 36               0.0100                True                               0.8
# 37               0.0001                True                               0.8
# 38               0.0100                True                               0.8
# 39               0.0100                True                               0.8
# 40               0.0010                True                               0.8
# 41               0.0100                True                               0.8
# 42               0.0001                True                               0.3
#
#     params_positive_reward_good_wafer  params_prioritized_replay  \
# 0                                 1.0                       True
# 1                                 0.5                      False
# 2                                 1.0                       True
# 3                                 0.3                      False
# 4                                 0.5                       True
# 5                                 0.8                      False
# 6                                 0.8                      False
# 7                                 0.3                      False
# 8                                 0.5                      False
# 9                                 0.5                       True
# 10                                0.3                      False
# 11                                1.0                       True
# 12                                1.0                       True
# 13                                1.0                       True
# 14                                0.3                       True
# 15                                0.3                       True
# 16                                0.3                      False
# 17                                0.3                      False
# 18                                0.3                      False
# 19                                0.3                      False
# 20                                0.3                      False
# 21                                0.8                      False
# 22                                0.3                      False
# 23                                0.3                      False
# 24                                0.3                      False
# 25                                0.3                      False
# 26                                0.3                      False
# 27                                0.3                      False
# 28                                0.3                      False
# 29                                0.8                      False
# 30                                1.0                      False
# 31                                1.0                      False
# 32                                0.3                      False
# 33                                0.3                      False
# 34                                0.3                      False
# 35                                0.3                      False
# 36                                0.3                      False
# 37                                0.3                      False
# 38                                0.5                      False
# 39                                1.0                      False
# 40                                0.8                      False
# 41                                0.3                      False
# 42                                0.5                       True
#
#     params_prioritized_replay_alpha  params_prioritized_replay_beta0  \
# 0                              0.60                              0.5
# 1                               NaN                              NaN
# 2                              0.70                              0.4
# 3                               NaN                              NaN
# 4                              0.60                              0.6
# 5                               NaN                              NaN
# 6                               NaN                              NaN
# 7                               NaN                              NaN
# 8                               NaN                              NaN
# 9                              0.65                              0.6
# 10                              NaN                              NaN
# 11                             0.70                              0.4
# 12                             0.70                              0.4
# 13                             0.70                              0.4
# 14                             0.70                              0.4
# 15                             0.65                              0.5
# 16                              NaN                              NaN
# 17                              NaN                              NaN
# 18                              NaN                              NaN
# 19                              NaN                              NaN
# 20                              NaN                              NaN
# 21                              NaN                              NaN
# 22                              NaN                              NaN
# 23                              NaN                              NaN
# 24                              NaN                              NaN
# 25                              NaN                              NaN
# 26                              NaN                              NaN
# 27                              NaN                              NaN
# 28                              NaN                              NaN
# 29                              NaN                              NaN
# 30                              NaN                              NaN
# 31                              NaN                              NaN
# 32                              NaN                              NaN
# 33                              NaN                              NaN
# 34                              NaN                              NaN
# 35                              NaN                              NaN
# 36                              NaN                              NaN
# 37                              NaN                              NaN
# 38                              NaN                              NaN
# 39                              NaN                              NaN
# 40                              NaN                              NaN
# 41                              NaN                              NaN
# 42                             0.65                              0.6
#
#     params_target_network_update_freq     state
# 0                                1500  COMPLETE
# 1                                 500  COMPLETE
# 2                                1000  COMPLETE
# 3                                1500  COMPLETE
# 4                                 500  COMPLETE
# 5                                1500  COMPLETE
# 6                                1500  COMPLETE
# 7                                 500  COMPLETE
# 8                                1500  COMPLETE
# 9                                1500  COMPLETE
# 10                               1000  COMPLETE
# 11                               1000   RUNNING
# 12                               1000  COMPLETE
# 13                               1000  COMPLETE
# 14                               1000  COMPLETE
# 15                               1000  COMPLETE
# 16                               1500  COMPLETE
# 17                               1500  COMPLETE
# 18                               1500  COMPLETE
# 19                               1500  COMPLETE
# 20                               1500  COMPLETE
# 21                               1500  COMPLETE
# 22                               1500  COMPLETE
# 23                               1500  COMPLETE
# 24                               1500  COMPLETE
# 25                               1500  COMPLETE
# 26                                500  COMPLETE
# 27                               1500  COMPLETE
# 28                               1500  COMPLETE
# 29                               1500  COMPLETE
# 30                               1500   RUNNING
# 31                               1500  COMPLETE
# 32                               1500  COMPLETE
# 33                               1500  COMPLETE
# 34                               1500  COMPLETE
# 35                                500  COMPLETE
# 36                                500  COMPLETE
# 37                                500  COMPLETE
# 38                                500  COMPLETE
# 39                                500  COMPLETE
# 40                                500  COMPLETE
# 41                                500  COMPLETE
# 42                                500  COMPLETE
#
# [43 rows x 25 columns]

# %%
from optuna.visualization import plot_param_importances
plot_param_importances(study)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="5b6e1105-bb89-4108-8d1b-aa26e71fcdae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5b6e1105-bb89-4108-8d1b-aa26e71fcdae")) {                    Plotly.newPlot(                        "5b6e1105-bb89-4108-8d1b-aa26e71fcdae",                        [{"cliponaxis":false,"hovertemplate":["target_network_update_freq (CategoricalDistribution): 0.0024210808506344977<extra></extra>","double_q (CategoricalDistribution): 0.0026714589074157287<extra></extra>","exploration_final_eps (CategoricalDistribution): 0.006718647629951932<extra></extra>","param_noise (CategoricalDistribution): 0.007612208449452696<extra></extra>","layer_2 (CategoricalDistribution): 0.008153385257583329<extra></extra>","layer_normalization (CategoricalDistribution): 0.012181292938649608<extra></extra>","exploration_fraction (CategoricalDistribution): 0.012797485654816181<extra></extra>","prioritized_replay (CategoricalDistribution): 0.013237345964137172<extra></extra>","learning_rate (CategoricalDistribution): 0.01949768414314216<extra></extra>","negative_reward_good_wafer (CategoricalDistribution): 0.024211298958472613<extra></extra>","learning_starts (CategoricalDistribution): 0.028182023661870306<extra></extra>","layer_1 (CategoricalDistribution): 0.030296325146414033<extra></extra>","gamma (CategoricalDistribution): 0.03170167936994335<extra></extra>","buffer_size (CategoricalDistribution): 0.04512459890544843<extra></extra>","param_lambda (CategoricalDistribution): 0.0664733901006273<extra></extra>","negative_reward_bad_wafer (CategoricalDistribution): 0.08036805495742384<extra></extra>","dueling (CategoricalDistribution): 0.10634154478930394<extra></extra>","positive_reward_good_wafer (CategoricalDistribution): 0.11162603850038912<extra></extra>","batch_size (CategoricalDistribution): 0.19470406944387947<extra></extra>","positive_reward_bad_wafer (CategoricalDistribution): 0.19568038637044424<extra></extra>"],"marker":{"color":"rgb(66,146,198)"},"orientation":"h","text":["0.0024210808506344977","0.0026714589074157287","0.006718647629951932","0.007612208449452696","0.008153385257583329","0.012181292938649608","0.012797485654816181","0.013237345964137172","0.01949768414314216","0.024211298958472613","0.028182023661870306","0.030296325146414033","0.03170167936994335","0.04512459890544843","0.0664733901006273","0.08036805495742384","0.10634154478930394","0.11162603850038912","0.19470406944387947","0.19568038637044424"],"textposition":"outside","texttemplate":"%{text:.2f}","x":[0.0024210808506344977,0.0026714589074157287,0.006718647629951932,0.007612208449452696,0.008153385257583329,0.012181292938649608,0.012797485654816181,0.013237345964137172,0.01949768414314216,0.024211298958472613,0.028182023661870306,0.030296325146414033,0.03170167936994335,0.04512459890544843,0.0664733901006273,0.08036805495742384,0.10634154478930394,0.11162603850038912,0.19470406944387947,0.19568038637044424],"y":["target_network_update_freq","double_q","exploration_final_eps","param_noise","layer_2","layer_normalization","exploration_fraction","prioritized_replay","learning_rate","negative_reward_good_wafer","learning_starts","layer_1","gamma","buffer_size","param_lambda","negative_reward_bad_wafer","dueling","positive_reward_good_wafer","batch_size","positive_reward_bad_wafer"],"type":"bar"}],                        {"showlegend":false,"title":{"text":"Hyperparameter Importances"},"xaxis":{"title":{"text":"Importance for Objective Value"}},"yaxis":{"title":{"text":"Hyperparameter"}},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barp ...

# %% [markdown]
# ## Conclusion
# trial 35 reaches the best gm
# - 1.Fold: 20.000 training steps
# - 2.Fold: 45.000 training steps
# - 3.Fold: 15.000 training steps
# - 4.Fold: 20.000 training steps
#
# --> Training on all training data with a training steps length of mean(20,45,15,20) = 25.000

# %% [markdown]
# # Train best model

# %%
# !python -W ignore train.py --path '../models/best_models/best_model_gm/' --study_name 'hyperstudy_gm' --timesteps 25000 --custom_callback --train_best_hypermodel
# Out:
# ---------------------------------------------------------------------------------------
# Model Evaluation on TRAINING DATA (last 100 episodes)
# ---------------------------------------------------------------------------------------
# [2.00%/100%] train_steps 500 (eps 331), mean_reward: 0.04 +/- 0.50, acc: 0.73, mean_timesteps: 1.46 +/- 1.09
# [4.00%/100%] train_steps 1000 (eps 539), mean_reward: -0.12 +/- 0.57, acc: 0.63, mean_timesteps: 2.72 +/- 4.44
# [6.00%/100%] train_steps 1500 (eps 697), mean_reward: -0.15 +/- 0.68, acc: 0.63, mean_timesteps: 3.03 +/- 6.28
# [8.00%/100%] train_steps 2000 (eps 950), mean_reward: -0.06 +/- 0.62, acc: 0.64, mean_timesteps: 1.92 +/- 3.20
# [10.00%/100%] train_steps 2500 (eps 1194), mean_reward: 0.02 +/- 0.59, acc: 0.71, mean_timesteps: 2.08 +/- 3.68
# [12.00%/100%] train_steps 3000 (eps 1435), mean_reward: -0.05 +/- 0.56, acc: 0.70, mean_timesteps: 2.44 +/- 5.12
# [14.00%/100%] train_steps 3500 (eps 1681), mean_reward: -0.10 +/- 0.60, acc: 0.63, mean_timesteps: 1.76 +/- 2.94
# [16.00%/100%] train_steps 4000 (eps 1882), mean_reward: -0.06 +/- 0.59, acc: 0.65, mean_timesteps: 1.26 +/- 0.84
# [18.00%/100%] train_steps 4500 (eps 2121), mean_reward: -0.18 +/- 0.62, acc: 0.57, mean_timesteps: 1.36 +/- 1.35
# [20.00%/100%] train_steps 5000 (eps 2403), mean_reward: -0.06 +/- 0.59, acc: 0.66, mean_timesteps: 1.61 +/- 2.10
# [22.00%/100%] train_steps 5500 (eps 2687), mean_reward: -0.05 +/- 0.57, acc: 0.71, mean_timesteps: 1.69 +/- 3.29
# [24.00%/100%] train_steps 6000 (eps 3034), mean_reward: 0.03 +/- 0.59, acc: 0.71, mean_timesteps: 1.35 +/- 0.94
# [26.00%/100%] train_steps 6500 (eps 3350), mean_reward: 0.01 +/- 0.54, acc: 0.74, mean_timesteps: 1.57 +/- 1.97
# [28.00%/100%] train_steps 7000 (eps 3652), mean_reward: -0.03 +/- 0.61, acc: 0.66, mean_timesteps: 1.67 +/- 2.17
# [30.00%/100%] train_steps 7500 (eps 3906), mean_reward: 0.03 +/- 0.55, acc: 0.73, mean_timesteps: 2.18 +/- 3.08
# [32.00%/100%] train_steps 8000 (eps 4141), mean_reward: -0.05 +/- 0.58, acc: 0.69, mean_timesteps: 1.87 +/- 4.16
# [34.00%/100%] train_steps 8500 (eps 4364), mean_reward: -0.01 +/- 0.61, acc: 0.68, mean_timesteps: 1.98 +/- 2.74
# [36.00%/100%] train_steps 9000 (eps 4583), mean_reward: -0.10 +/- 0.67, acc: 0.65, mean_timesteps: 2.83 +/- 8.27
# [38.00%/100%] train_steps 9500 (eps 4793), mean_reward: -0.08 +/- 0.60, acc: 0.65, mean_timesteps: 1.50 +/- 1.83
# [40.00%/100%] train_steps 10000 (eps 5089), mean_reward: 0.07 +/- 0.59, acc: 0.74, mean_timesteps: 1.46 +/- 1.51
# [42.00%/100%] train_steps 10500 (eps 5404), mean_reward: -0.05 +/- 0.57, acc: 0.70, mean_timesteps: 1.29 +/- 1.28
# [44.00%/100%] train_steps 11000 (eps 5684), mean_reward: 0.09 +/- 0.57, acc: 0.75, mean_timesteps: 1.84 +/- 3.36
# [46.00%/100%] train_steps 11500 (eps 6003), mean_reward: -0.04 +/- 0.60, acc: 0.66, mean_timesteps: 1.49 +/- 2.83
# [48.00%/100%] train_steps 12000 (eps 6246), mean_reward: -0.08 +/- 0.64, acc: 0.66, mean_timesteps: 2.72 +/- 8.93
# [50.00%/100%] train_steps 12500 (eps 6548), mean_reward: -0.08 +/- 0.64, acc: 0.62, mean_timesteps: 1.89 +/- 3.23
# [52.00%/100%] train_steps 13000 (eps 6802), mean_reward: -0.10 +/- 0.66, acc: 0.65, mean_timesteps: 1.68 +/- 2.38
# [54.00%/100%] train_steps 13500 (eps 7082), mean_reward: -0.03 +/- 0.66, acc: 0.66, mean_timesteps: 1.63 +/- 2.39
# [56.00%/100%] train_steps 14000 (eps 7386), mean_reward: -0.07 +/- 0.62, acc: 0.65, mean_timesteps: 1.52 +/- 1.72
# [58.00%/100%] train_steps 14500 (eps 7628), mean_reward: -0.14 +/- 0.66, acc: 0.58, mean_timesteps: 1.90 +/- 4.95
# [60.00%/100%] train_steps 15000 (eps 7892), mean_reward: -0.11 +/- 0.67, acc: 0.60, mean_timesteps: 2.06 +/- 3.90
# [62.00%/100%] train_steps 15500 (eps 8142), mean_reward: -0.00 +/- 0.55, acc: 0.72, mean_timesteps: 1.42 +/- 1.44
# [64.00%/100%] train_steps 16000 (eps 8401), mean_reward: -0.02 +/- 0.65, acc: 0.67, mean_timesteps: 2.14 +/- 4.39
# [66.00%/100%] train_steps 16500 (eps 8609), mean_reward: -0.12 +/- 0.62, acc: 0.61, mean_timesteps: 2.56 +/- 3.99
# [68.00%/100%] train_steps 17000 (eps 8877), mean_reward: -0.03 +/- 0.57, acc: 0.69, mean_timesteps: 1.43 +/- 2.45
# [70.00%/100%] train_steps 17500 (eps 9081), mean_reward: -0.20 +/- 0.61, acc: 0.54, mean_timesteps: 1.98 +/- 2.75
# [72.00%/100%] train_steps 18000 (eps 9373), mean_reward: -0.06 +/- 0.64, acc: 0.65, mean_timesteps: 2.01 +/- 3.68
# [74.00%/100%] train_steps 18500 (eps 9627), mean_reward: -0.14 +/- 0.65, acc: 0.61, mean_timesteps: 2.42 +/- 4.61
# [76.00%/100%] train_steps 19000 (eps 9863), mean_reward: -0.11 +/- 0.67, acc: 0.62, mean_timesteps: 2.20 +/- 4.08
# [78.00%/100%] train_steps 19500 (eps 10094), mean_reward: -0.16 +/- 0.67, acc: 0.59, mean_timesteps: 2.51 +/- 6.50
# [80.00%/100%] train_steps 20000 (eps 10310), mean_reward: -0.05 +/- 0.62, acc: 0.66, mean_timesteps: 1.92 +/- 2.84
# [82.00%/100%] train_steps 20500 (eps 10503), mean_reward: -0.18 +/- 0.75, acc: 0.58, mean_timesteps: 3.19 +/- 6.42
# [84.00%/100%] train_steps 21000 (eps 10768), mean_reward: -0.19 +/- 0.68, acc: 0.55, mean_timesteps: 1.58 +/- 2.76
# [86.00%/100%] train_steps 21500 (eps 10997), mean_reward: -0.08 +/- 0.71, acc: 0.63, mean_timesteps: 2.04 +/- 3.12
# [88.00%/100%] train_steps 22000 (eps 11229), mean_reward: -0.26 +/- 0.67, acc: 0.51, mean_timesteps: 2.03 +/- 4.75
# [90.00%/100%] train_steps 22500 (eps 11520), mean_reward: -0.13 +/- 0.64, acc: 0.64, mean_timesteps: 1.71 +/- 1.85
# [92.00%/100%] train_steps 23000 (eps 11805), mean_reward: 0.03 +/- 0.62, acc: 0.70, mean_timesteps: 1.84 +/- 3.73
# [94.00%/100%] train_steps 23500 (eps 12052), mean_reward: -0.26 +/- 0.67, acc: 0.51, mean_timesteps: 2.28 +/- 4.06
# [96.00%/100%] train_steps 24000 (eps 12324), mean_reward: -0.08 +/- 0.63, acc: 0.65, mean_timesteps: 1.57 +/- 2.20
# [98.00%/100%] train_steps 24500 (eps 12608), mean_reward: -0.12 +/- 0.66, acc: 0.61, mean_timesteps: 2.22 +/- 4.83
# [100.00%/100%] train_steps 25000 (eps 12846), mean_reward: -0.14 +/- 0.63, acc: 0.63, mean_timesteps: 2.27 +/- 5.11
# 463.11546778678894

# %%
# !python -W ignore evaluate.py --path '../models/best_models/best_model_gm/' --study_name 'hyperstudy_gm' --train_best_hypermodel --evaluation_summary
# Out:
# Evaluation Summary on Test_Data ( 292 data points)
#                 model  mean_reward       acc  sensitivity  precision        f1  specificity        gm  mean_timesteps  mean_timesteps_good  mean_timesteps_bad best_mean_reward best_f1 best_sensitivity best_specificity best_acc best_gm
# 0  rl_model_final.zip     0.221173  0.863014     0.705882   0.590164  0.642857     0.896266  0.795398        2.085616             2.095238             2.04918                x       x                x                x        x       x
#
# Evaluation Summary on Train_Data ( 679 data points)
#                 model  mean_reward      acc  sensitivity  precision      f1  specificity        gm  mean_timesteps  mean_timesteps_good  mean_timesteps_bad best_mean_reward best_f1 best_sensitivity best_specificity best_acc best_gm
# 0  rl_model_final.zip     0.269472  0.89838     0.764706   0.689394  0.7251     0.926786  0.841854        2.098675             2.095064            2.113636                x       x                x                x        x       x
